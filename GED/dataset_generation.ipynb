# %% [markdown]
# ###**1. Load and Unzip BIGPATENT Data**

# %% [markdown]
# ####Need to run only once

# %%
#!sudo apt-get install -y gzip

# %%
#!tar -xf '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData.tar.gz'

# %%
#!mv /content/bigPatentData '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData'

# %%
#!tar -xvzf '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData/train.tar.gz'

# %%
#!tar -xvzf '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData/test.tar.gz'

# %%
#!tar -xvzf '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData/val.tar.gz'

# %%
#import json
#import gzip
#import os
#import sys

# %%
def readData(input_path,split_type):
  cpc_codes = ['a','b','c','d','e','f','g','h','y']
  data = []
  for code in cpc_codes:
    file_names = os.listdir(os.path.join(input_path,split_type,code))
    # reading one of the gz files.
    file_name = file_names[0]
    print("Reading file "+ file_name + " from "+ split_type+" split for cpc code " + code)
    
    with gzip.open(os.path.join(input_path,split_type,code,file_name),'r') as fin:
        for row in fin:
            json_obj = json.loads(row)
            json_obj['cpc_code'] = code
            data.append(json_obj)
  return data

# %% [markdown]
# ####Saving data as dataframes to Disk

# %%
#df_train = pd.DataFrame(data=readData('/content/','train'))
#df_test = pd.DataFrame(data=readData('/content/','test'))
#df_val = pd.DataFrame(data=readData('/content/','val'))

# %%
#df_train.to_csv('/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData_csv/train.csv',index=False)
#df_test.to_csv('/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData_csv/test.csv',index=False)
#df_val.to_csv('/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData_csv/val.csv',index=False)

# %% [markdown]
# ###**2. Methods to introduce grammatical errors in the dataset**

# %%
#!pip install pattern

# %%
#!pip install inflect==5.4.0

# %%
import pandas as pd
import numpy as np
import spacy
from random import randint
import random
from pattern.en import lexeme
import inflect
import re

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/bigPatentData_csv/train.csv')

# %%
df.columns
# Out:
# Index(['publication_number', 'abstract', 'application_number', 'description',
#        'cpc_code'],
#       dtype='object')

# %%
df.abstract[1]
# Out:
# 'the present invention provides a polypeptide tf1 for inhibiting type - 2 shiga - toxin activity , an encoding gene for the same and use thereof . the present polypeptide is named tf1 ; its amino acid sequence is shown in sequence 1 in the sequence list . the polypeptide p1 can be prepared into medicine for preventing and / or treating diseases caused by type - 2 shiga toxin or the pathogens which produce type - 2 shiga toxin .'

# %%
df_with_errors = df.sample(frac=0.3,random_state=3)
df_wo_errors = test_df = df[~df.index.isin(df_with_errors.index)]

# %%
df_with_errors.shape
# Out:
# (3712, 5)

# %%
df_wo_errors.shape
# Out:
# (8663, 5)

# %%
error_labels = np.zeros(shape=(df_with_errors.shape[0],6),dtype=int)
abstracts = np.array(df_with_errors.abstract)

# %% [markdown]
# ####2.1 Error 1: Verb form

# %%
def introduce_incorrect_verbs(abs_doc):
  nlp = spacy.load("en_core_web_sm")
  doc = nlp(abs_doc)
  arr_doc = []
  token_indexes = []
  
  #Find tokens Indexes that are verbs
  for token in doc:
    arr_doc.append(token.text)
    if token.pos_ == 'VERB':
      token_indexes.append(int(token.i))

  #Randomly select how many incorrect verbs are to be generated
  how_many_verbs = randint(0,len(token_indexes)-1)
  random_tokens = random.sample(token_indexes,how_many_verbs)

  #Changing verbs in the document, introducing incorrect verbs error
  changed = False
  for i in random_tokens:
      verb = str(doc[i])
      lexical_verbs = lexeme(verb)
      if len(lexical_verbs) > 2:
        try:
          lexical_verbs.remove(verb)
        except ValueError:
          pass
        print(lexical_verbs)
        arr_doc[i] = lexical_verbs[randint(0,len(lexical_verbs)-1)]
        changed = True


  return changed,' '.join([str(i) for i in arr_doc])

# %% [markdown]
# ####2.2 Error 2: Singluar-Plural Error

# %%
def introduce_singular_plural_error(abs_doc):
  p = inflect.engine()
  nlp = spacy.load("en_core_web_sm")
  doc = nlp(abs_doc)
  arr_doc = []
  token_indexes = []
  
  #Find tokens Indexes that are verbs
  for token in doc:
    arr_doc.append(token.text)
    if token.pos_ == 'NOUN' or token.pos_ == 'PRON':
      token_indexes.append(int(token.i))
  
  #Randomly select how many incorrect singulars/plurals are to be generated
  how_many_words = randint(1,len(token_indexes)-1)
  random_tokens = random.sample(token_indexes,how_many_words)

  #Changing words in the document, introducing singular/plural error
  for i in random_tokens:
    word = str(doc[i])
    sing = p.singular_noun(str(word))
    if sing == False:
      arr_doc[i] = p.plural(word)
    else:
      arr_doc[i] = p.singular_noun(word)
  return ' '.join([str(i) for i in arr_doc])

# %% [markdown]
# ####2.3 Error 3: Article Error

# %%
def introduce_article_error(abs_doc):
  nlp = spacy.load("en_core_web_sm")
  doc = nlp(abs_doc)
  arr_doc = []
  token_indexes = []
  
  #Find tokens Indexes that are verbs
  for token in doc:
    arr_doc.append(token.text)
    if token.pos_ == 'DET':
      token_indexes.append(int(token.i))
  changed = False
  #Randomly select how many incorrect verbs are to be generated
  if len(token_indexes) > 1:
    how_many_words = randint(1,len(token_indexes)-1)
    random_tokens = random.sample(token_indexes,how_many_words)

    #Changing articles in the document, introducing article error
    for i in random_tokens:
      article_word = str(doc[i])
      articles = ['a','an','the']
      try:
        articles.remove(article_word)
      except ValueError:
        pass
      
      arr_doc[i] = random.sample(articles,1)[0]
      changed = True

  return changed,' '.join([str(i) for i in arr_doc])

# %% [markdown]
# ####2.4 Incorrect word use error

# %%
def introduce_incorrect_word_error(abs_doc):
  file_name = '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/homonyms.csv'
  lines = []
  with open(file_name,'rt',encoding='utf-8-sig') as file:
    lines = file.readlines()
  homonyms = [i.split(',') for i in [re.sub('"','',line.strip()) for line in lines]]
  for i in range(len(homonyms)):
    if (len(homonyms[i]) < 4):
      how_many_missing = 4 - len(homonyms[i])
      for j in range(how_many_missing):
        homonyms[i].append('NaN')

  
  arr_doc = abs_doc.split(' ')
  columns = list(zip(*homonyms))
 
  col1_matching = []
  col2_matching = []
  col3_matching = []
  col4_matching = []

  unique_words = []
  for i in range(len(arr_doc)):

    if arr_doc[i] in columns[3] and arr_doc[i] not in unique_words:
      col4_matching.append(i)
      unique_words.append(arr_doc[i])
    elif arr_doc[i] in columns[2] and arr_doc[i] not in unique_words:
      col3_matching.append(i)
      unique_words.append(arr_doc[i])
    elif arr_doc[i] in columns[1] and arr_doc[i] not in unique_words:
      col2_matching.append(i)
      unique_words.append(arr_doc[i])
    elif arr_doc[i] in columns[0] and arr_doc[i] not in unique_words:
      col1_matching.append(i)
      unique_words.append(arr_doc[i])
    
  
  replacable_word_count = len(col1_matching)+len(col2_matching)+len(col3_matching)+len(col4_matching)

  random_num = randint(0,replacable_word_count)

  flag = 0
  if len(col1_matching) > 0:
    for ind in col1_matching:
      index_in_col_1 = columns[0].index(arr_doc[ind])
      print("Replacing ",arr_doc[ind]," with ",columns[1][index_in_col_1])
      replaced_text = columns[1][index_in_col_1]
      arr_doc[ind] = replaced_text
      print(arr_doc[ind])
      flag = flag + 1
      if flag == random_num:
        break
  
  if len(col2_matching) > 0:
    for ind in col2_matching:
      index_in_col_2 = columns[1].index(arr_doc[ind])
      print("Replacing ",arr_doc[ind]," with ",columns[0][index_in_col_2])
      replaced_text = columns[0][index_in_col_2]
      arr_doc[ind] = replaced_text.strip()
      print(arr_doc[ind])
      flag = flag + 1
      if flag == random_num:
        break

  if len(col3_matching) > 0:
    for ind in col3_matching:
      index_in_col_3 = columns[2].index(arr_doc[ind])
      print("Replacing ",arr_doc[ind]," with ",columns[1][index_in_col_3])
      replaced_text = columns[1][index_in_col_3]
      arr_doc[ind] = replaced_text.strip()
      print(arr_doc[ind])
      flag = flag + 1
      if flag == random_num:
        break
  if len(col4_matching) > 0:
    for ind in col4_matching:
      index_in_col_4 = columns[3].index(arr_doc[ind])
      print("Replacing ",arr_doc[ind]," with ",columns[0][index_in_col_4])
      replaced_text = columns[0][index_in_col_4]
      arr_doc[ind] = replaced_text.strip()
      print(arr_doc[ind])
      flag = flag + 1
      if flag == random_num:
        break

  return ' '.join([i.strip() for i in arr_doc])

# %%
introduce_incorrect_word_error(abstracts[5])
# Out:
# Replacing  to  with  too
# too
# Replacing  review  with  revue
# revue
# Replacing  for  with  fore
# fore
# 'the present invention relates too circuit defect detection , classification , and revue in the wafer stage of the integrated circuit semiconductor device manufacturing process . the method of processing integrated circuit semiconductor dice on a wafer in a manufacturing process fore dice comprising the steps of visually inspecting said dice on said wafer to determine defects thereon , summarizing the number , types , and ranges of sizes of the defects of said dice on said wafer , and determining if said wafer is acceptable to proceed in said manufacturing process .'

# %%
"['fore']"
# Out:
# "['fore']"

# %% [markdown]
# ####2.5 Spelling errors

# %%
def introduce_spelling_errors(abs_doc):
  file_name = '/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/Annotations.csv'
  lines = []
  with open(file_name,'rt',encoding='utf-8-sig') as file:
    lines = file.readlines()
  misspell_data = [i.split(',') for i in [re.sub('"','',line.strip()) for line in lines]]
  misspell_data = misspell_data[1:]
  columns = list(zip(*misspell_data))
  original_text = columns[4]
  misspelled_text = columns[2]

  words_eligble = []
  arr_doc = abs_doc.split(' ')

  inserted_index = []
  for i in range(len(arr_doc)):
    if arr_doc[i] in original_text:
      index_in_org = original_text.index(arr_doc[i])
      if index_in_org not in inserted_index:
        words_eligble.append([i,index_in_org])
        inserted_index.append(index_in_org)
  
  
  random_error_count = randint(1,len(words_eligble))
  words_to_be_replaced = random.sample(words_eligble,random_error_count)
  for i in words_to_be_replaced:
    print("Replacing ",arr_doc[i[0]], " with ",misspelled_text[i[1]])
    arr_doc[i[0]] = misspelled_text[i[1]]

  return ' '.join([str(i) for i in arr_doc])

# %%
introduce_spelling_errors(abstracts[5])
# Out:
# Replacing  in  with  ?n
# Replacing  determine  with  detrermine
# Replacing  and  with  und
# Replacing  said  with  saied
# Replacing  method  with  methord
# Replacing  the  with  rthe
# Replacing  acceptable  with  aceptable
# Replacing  of  with  pf
# Replacing  to  with  ti
# Replacing  manufacturing  with  manifacturing
# Replacing  on  with  om
# Replacing  number  with  numer
# Replacing  for  with  foir
# Replacing  present  with  pesent
# Replacing  types  with  tipes
# Replacing  process  with  procces
# Replacing  if  with  uf
# Replacing  invention  with  invetion
# 'rthe pesent invetion relates ti circuit defect detection , classification , und review ?n the wafer stage pf the integrated circuit semiconductor device manifacturing procces . the methord of processing integrated circuit semiconductor dice om a wafer in a manufacturing process foir dice comprising the steps of visually inspecting saied dice on said wafer to detrermine defects thereon , summarizing the numer , tipes , and ranges of sizes of the defects of said dice on said wafer , and determining uf said wafer is aceptable to proceed in said manufacturing process .'

# %% [markdown]
# ###3. Efficiently Introduce Errors

# %%
count = int(0.3*abstracts.shape[0])

# %%
abstracts_random_indexes = np.random.randint(0,abstracts.shape[0],count)
for i in abstracts_random_indexes:
  flag, abstract_w_error = introduce_incorrect_verbs(abstracts[i])
  if flag == True:
    abstracts[i] = abstract_w_error
    error_labels[i,0]=1
    error_labels[i,5]=1
# Out:
# Streaming output truncated to the last 5000 lines.
# ['provide', 'provides', 'providing']
# ['adjust', 'adjusts', 'adjusted']
# ['connect', 'connects', 'connected']
# ['fees', 'feeing']
# ['maintains', 'maintaining', 'maintained']
# ['enable', 'enables', 'enabled']
# ['desire', 'desires', 'desiring']
# ['allows', 'allowing', 'allowed']
# ['decrease', 'decreases', 'decreasing']
# ['increase', 'increases', 'increasing']
# ['achieve', 'achieves', 'achieving']
# ['demonstrate', 'demonstrating', 'demonstrated']
# ['allows', 'allowing', 'allowed']
# ['precipitates', 'precipitating', 'precipitated']
# ['administer', 'administers', 'administering']
# ['res', 'ring', 'red']
# ['requires', 'requiring', 'required']
# ['dissolves', 'dissolving', 'dissolved']
# ['insures', 'insuring', 'insured']
# ['suspends', 'suspending', 'suspended']
# ['deliver', 'delivers', 'delivered']
# ['-s', '-ing', '-ed']
# ['draw', 'draws', 'drawing', 'drew']
# ['cause', 'causes', 'caused']
# ['cause', 'causing', 'caused']
# ['raise', 'raises', 'raising']
# ['close', 'closing', 'closed']
# ['provide', 'provides', 'providing']
# ['prevents', 'preventing', 'prevented']
# ['open', 'opening', 'opened']
# ['draws', 'drawing', 'drew', 'drawn']
# ['guide', 'guides', 'guiding']
# ['experience', 'experiences', 'experiencing']
# ['place', 'places', 'placing']
# ['could', "can't", "couldn't"]
# ['mayest', "mayn't"]
# ['make', 'makes', 'making']
# ['find', 'finds', 'finding']
# ['compress', 'compresses', 'compressing']
# ['address', 'addresses', 'addressing', 'addrest']
# ['harden', 'hardens', 'hardening']
# ['couple', 'couples', 'coupling']
# ['provides', 'providing', 'provided']
# ['subject', 'subjects', 'subjecting']
# ['desire', 'desires', 'desiring']
# ['feed', 'fees', 'feeing']
# ['tightens', 'tightening', 'tightened']
# ['comprise', 'comprises', 'comprising']
# ['controls', 'controlling', 'controlled']
# ['make', 'makes', 'making']
# ['initiate', 'initiates', 'initiating']
# ['mayest', "mayn't"]
# ['disclose', 'discloses', 'disclosing']
# ['runs', 'running', 'ran']
# ['provides', 'providing', 'provided']
# ['dope', 'dopes', 'doped']
# ['contain', 'contains', 'contained']
# ['cause', 'causes', 'causing']
# ['used', 'uses']
# ['dope', 'dopes', 'doped']
# ['grow', 'grows', 'grew', 'grown']
# ['implant', 'implants', 'implanted']
# ['prevents', 'preventing', 'prevented']
# ['adapt', 'adapts', 'adapting']
# ['fabricate', 'fabricates', 'fabricated']
# ['used', 'uses']
# ['include', 'including', 'included']
# ['dope', 'dopes', 'doped']
# ['dope', 'dopes', 'doped']
# ['bombard', 'bombards', 'bombarding']
# ['form', 'forms', 'formed']
# ['adapt', 'adapts', 'adapting']
# ['dope', 'dopes', 'doped']
# ['perform', 'performs', 'performed']
# ['removes', 'removing', 'removed']
# ['inject', 'injects', 'injecting']
# ['relate', 'relating', 'related']
# ['form', 'forms', 'forming']
# ['anneal', 'anneals', 'annealed']
# ['fabricate', 'fabricates', 'fabricated']
# ['removes', 'removing', 'removed']
# ['perform', 'performs', 'performed']
# ['anchor', 'anchors', 'anchored']
# ['guides', 'guiding', 'guided']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['carry', 'carries', 'carrying']
# ['move', 'moves', 'moved']
# ['case', 'cases', 'cased']
# ['include', 'including', 'included']
# ['tube', 'tubes', 'tubed']
# ['engage', 'engages', 'engaging']
# ['cut', 'cutting']
# ['support', 'supports', 'supported']
# ['mayest', "mayn't"]
# ['fills', 'filling', 'filled']
# ['empties', 'emptying', 'emptied']
# ['select', 'selects', 'selected']
# ['store', 'stores', 'storing']
# ['indicate', 'indicates', 'indicating']
# ['mayest', "mayn't"]
# ['select', 'selects', 'selecting']
# ['indicate', 'indicates', 'indicated']
# ['indicate', 'indicates', 'indicated']
# ['select', 'selects', 'selecting']
# ['treat', 'treating', 'treated']
# ['select', 'selects', 'selecting']
# ['indicate', 'indicates', 'indicating']
# ['select', 'selects', 'selecting']
# ['combine', 'combines', 'combined']
# ['disclose', 'discloses', 'disclosing']
# ['treat', 'treats', 'treated']
# ['forms', 'forming', 'formed']
# ['indicates', 'indicating', 'indicated']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['operate', 'operates', 'operating']
# ['indicate', 'indicates', 'indicated']
# ['stitch', 'stitches', 'stitching']
# ['store', 'stores', 'storing']
# ['changes', 'changing', 'changed']
# ['construct', 'constructs', 'constructing']
# ['leads', 'leading', 'led']
# ['come', 'coming', 'came']
# ['provide', 'provides', 'providing']
# ['base', 'bases', 'basing']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['cut', 'cuts']
# ['advance', 'advances', 'advancing']
# ['complete', 'completes', 'completing']
# ['support', 'supports', 'supporting']
# ['provide', 'provides', 'providing']
# ['select', 'selects', 'selecting']
# ['includes', 'including', 'included']
# ['provide', 'provides', 'providing']
# ['fees', 'feeing']
# ['provide', 'provides', 'providing']
# ['sew', 'sews', 'sewing', 'sewed']
# ['aligns', 'aligning', 'aligned']
# ['mean', 'meaning', 'meant']
# ['comprise', 'comprising', 'comprised']
# ['senses', 'sensing', 'sensed']
# ['controls', 'controlling', 'controlled']
# ['form', 'forms', 'forming']
# ['extend', 'extending', 'extended']
# ['sew', 'sews', 'sewing', 'sewed']
# ['sense', 'senses', 'sensed']
# ['support', 'supports', 'supported']
# ['accord', 'accords', 'accorded']
# ['add', 'adds', 'added']
# ['forms', 'forming', 'formed']
# ['overlaps', 'overlapping', 'overlapped']
# ['enables', 'enabling', 'enabled']
# ['remain', 'remains', 'remained']
# ['distribute', 'distributes', 'distributing']
# ['transfer', 'transfers', 'transferring']
# ['attach', 'attaches', 'attaching']
# ['bond', 'bonds', 'bonding']
# ['embed', 'embeds', 'embedding']
# ['bond', 'bonds', 'bonding']
# ['descends', 'descending', 'descended']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['implement', 'implements', 'implementing']
# ['tests', 'testing', 'tested']
# ['provide', 'providing', 'provided']
# ['desire', 'desires', 'desiring']
# ['resolves', 'resolving', 'resolved']
# ['overcome', 'overcoming', 'overcame']
# ['implement', 'implements', 'implementing']
# ['resets', 'resetting']
# ['integrate', 'integrates', 'integrating']
# ['reduce', 'reduces', 'reducing']
# ['holds', 'holding', 'held']
# ['include', 'including', 'included']
# ['include', 'including', 'included']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['comprise', 'comprises', 'comprised']
# ['say', 'says', 'saying']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['consist', 'consists', 'consisted']
# ['position', 'positions', 'positioned']
# ['fasten', 'fastens', 'fastened']
# ['seal', 'seals', 'sealed']
# ['fasten', 'fastens', 'fastened']
# ['reposition', 'repositions', 'repositioned']
# ['satisfies', 'satisfying', 'satisfied']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['provide', 'provides', 'providing']
# ['connect', 'connects', 'connected']
# ['mount', 'mounts', 'mounting']
# ['sets', 'setting']
# ['serve', 'serves', 'served']
# ['mount', 'mounts', 'mounting']
# ['improve', 'improves', 'improved']
# ['achieve', 'achieves', 'achieved']
# ['cut', 'cuts']
# ['secures', 'securing', 'secured']
# ['secure', 'secures', 'secured']
# ['position', 'positions', 'positioning']
# ['contour', 'contours', 'contouring']
# ['produce', 'produces', 'producing']
# ['hold', 'holds', 'held']
# ['weld', 'welds', 'welded']
# ['cut', 'cuts']
# ['hold', 'holds', 'holding']
# ['supports', 'supporting', 'supported']
# ['undergo', 'undergoing', 'underwent', 'undergone']
# ['say', 'says', 'saying']
# ['relate', 'relating', 'related']
# ['used', 'uses']
# ['indwell', 'indwells', 'indwelt']
# ['comprise', 'comprises', 'comprised']
# ['say', 'says', 'saying']
# ['plays', 'playing', 'played']
# ['could', "can't", "couldn't"]
# ['include', 'including', 'included']
# ['activate', 'activates', 'activated']
# ['comprise', 'comprising', 'comprised']
# ['uses', 'using']
# ['react', 'reacts', 'reacted']
# ['produces', 'producing', 'produced']
# ['produce', 'produces', 'produced']
# ['allows', 'allowing', 'allowed']
# ['crawl', 'crawls', 'crawled']
# ['controls', 'controlling', 'controlled']
# ['could', "can't", "couldn't"]
# ['deform', 'deforms', 'deforming']
# ['secures', 'securing', 'secured']
# ['places', 'placing', 'placed']
# ['creates', 'creating', 'created']
# ['willing', 'willed', "won't"]
# ['willing', 'willed', "won't"]
# ['fix', 'fixes', 'fixing']
# ['abuts', 'abutting', 'abutted']
# ['pack', 'packs', 'packed']
# ['pack', 'packs', 'packed']
# ['used', 'uses']
# ['oppose', 'opposes', 'opposed']
# ['occupies', 'occupying', 'occupied']
# ['surrounds', 'surrounding', 'surrounded']
# ['fit', 'fits', 'fitting']
# ['transmit', 'transmits', 'transmitting']
# ['encodes', 'encoding', 'encoded']
# ['disclose', 'discloses', 'disclosing']
# ['provide', 'providing', 'provided']
# ['result', 'results', 'resulted']
# ['encode', 'encodes', 'encoded']
# ['expect', 'expects', 'expecting']
# ['construct', 'constructs', 'constructed']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['enhances', 'enhancing', 'enhanced']
# ['provides', 'providing', 'provided']
# ['transmit', 'transmits', 'transmitting']
# ['expect', 'expects', 'expecting']
# ['accomplish', 'accomplishes', 'accomplishing']
# ['uses', 'using']
# ['code', 'codes', 'coded']
# ['climb', 'climbs', 'climbed']
# ['stick', 'sticks', 'sticking']
# ['present', 'presents', 'presenting']
# ['fall', 'falls', 'fell', 'fallen']
# ['prevents', 'preventing', 'prevented']
# ['provide', 'provides', 'provided']
# ['replenishes', 'replenishing', 'replenished']
# ['supply', 'supplies', 'supplied']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['reduce', 'reduces', 'reduced']
# ['utilize', 'utilizes', 'utilized']
# ['compress', 'compresses', 'compressing']
# ['provides', 'providing', 'provided']
# ['charge', 'charges', 'charged']
# ['connect', 'connects', 'connecting']
# ['drive', 'drives', 'driving', 'drove']
# ['pressurize', 'pressurizes', 'pressurizing']
# ['used', 'uses']
# ['remove', 'removes', 'removing']
# ['secure', 'secures', 'securing']
# ['clamp', 'clamps', 'clamping']
# ['say', 'says', 'saying']
# ['provides', 'providing', 'provided']
# ['seal', 'seals', 'sealing']
# ['connect', 'connects', 'connecting']
# ['establish', 'establishes', 'establishing']
# ['oppose', 'opposes', 'opposing']
# ['interconnect', 'interconnects', 'interconnecting']
# ['receive', 'receiving', 'received']
# ['connect', 'connects', 'connecting']
# ['form', 'forms', 'formed']
# ['receive', 'receives', 'received']
# ['carry', 'carries', 'carrying']
# ['open', 'opens', 'opened']
# ['provides', 'providing', 'provided']
# ['form', 'forms', 'forming']
# ['form', 'forms', 'forming']
# ['transport', 'transports', 'transported']
# ['arrive', 'arrives', 'arrived']
# ['weld', 'welds', 'welding']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['extend', 'extending', 'extended']
# ['delaminate', 'delaminates', 'delaminated']
# ['prevent', 'preventing', 'prevented']
# ['provide', 'provides', 'providing']
# ['attack', 'attacks', 'attacked']
# ['apply', 'applies', 'applying']
# ['hold', 'holds', 'holding']
# ['equalizes', 'equalizing', 'equalized']
# ['affect', 'affects', 'affecting']
# ['attach', 'attaches', 'attaching']
# ['detaches', 'detaching', 'detached']
# ['detach', 'detaches', 'detaching']
# ['extend', 'extends', 'extended']
# ['extend', 'extending', 'extended']
# ['prevents', 'preventing', 'prevented']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['perform', 'performs', 'performing']
# ['receive', 'receives', 'receiving']
# ['mayest', "mayn't"]
# ['receive', 'receives', 'received']
# ['includes', 'including', 'included']
# ['determine', 'determines', 'determined']
# ['mount', 'mounts', 'mounting']
# ['arrange', 'arranges', 'arranging']
# ['could', "can't", "couldn't"]
# ['could', "can't", "couldn't"]
# ['oppose', 'opposes', 'opposing']
# ['determine', 'determines', 'determined']
# ['acts', 'acting', 'acted']
# ['prevent', 'prevents', 'preventing']
# ['disclose', 'discloses', 'disclosing']
# ['could', "can't", "couldn't"]
# ['accord', 'accords', 'accorded']
# ['supplies', 'supplying', 'supplied']
# ['adjust', 'adjusts', 'adjusted']
# ['arrange', 'arranges', 'arranging']
# ['integrate', 'integrates', 'integrated']
# ['emit', 'emits', 'emitted']
# ['apply', 'applies', 'applied']
# ['connect', 'connects', 'connecting']
# ['drive', 'drives', 'drove', 'driven']
# ['controls', 'controlling', 'controlled']
# ['include', 'includes', 'included']
# ['integrate', 'integrates', 'integrating']
# ['operate', 'operates', 'operated']
# ['operate', 'operates', 'operated']
# ['include', 'includes', 'included']
# ['provide', 'provides', 'provided']
# ['include', 'includes', 'included']
# ['provide', 'provides', 'provided']
# ['opens', 'opening', 'opened']
# ['determine', 'determines', 'determined']
# ['includes', 'including', 'included']
# ['mayest', "mayn't"]
# ['flows', 'flowing', 'flowed']
# ['pulsate', 'pulsates', 'pulsated']
# ['provide', 'provides', 'providing']
# ['eject', 'ejects', 'ejecting']
# ['enter', 'enters', 'entered']
# ['seal', 'seals', 'sealing']
# ['compress', 'compressing', 'compressed']
# ['identify', 'identifies', 'identifying']
# ['take', 'takes', 'taking', 'took']
# ['could', "can't", "couldn't"]
# ['uses', 'using', 'used']
# ['contour', 'contours', 'contouring']
# ['apply', 'applies', 'applying']
# ['deposit', 'deposits', 'deposited']
# ['turn', 'turns', 'turned']
# ['airflows', 'airflowing', 'airflowed']
# ['could', "can't", "couldn't"]
# ['control', 'controls', 'controlling']
# ['facilitate', 'facilitating', 'facilitated']
# ['include', 'including', 'included']
# ['make', 'makes', 'made']
# ['connects', 'connecting', 'connected']
# ['extend', 'extends', 'extending']
# ['tilt', 'tilts', 'tilted']
# ['could', "can't", "couldn't"]
# ['include', 'including', 'included']
# ['accomplish', 'accomplishes', 'accomplishing']
# ['coat', 'coats', 'coating']
# ['coat', 'coats', 'coating']
# ['mayest', "mayn't"]
# ['employ', 'employs', 'employed']
# ['base', 'bases', 'basing']
# ['overcome', 'overcoming', 'overcame']
# ['base', 'bases', 'basing']
# ['uses', 'using']
# ['seat', 'seats', 'seated']
# ['comprise', 'comprises', 'comprised']
# ['includes', 'including', 'included']
# ['associate', 'associates', 'associating']
# ['utilize', 'utilizes', 'utilized']
# ['make', 'making', 'made']
# ['extrude', 'extrudes', 'extruding']
# ['meet', 'meeting', 'met']
# ['performs', 'performing', 'performed']
# ['weave', 'weaves', 'weaving', 'wove']
# ['shape', 'shapes', 'shaping']
# ['combine', 'combines', 'combining']
# ['counteracts', 'counteracting', 'counteracted']
# ['shape', 'shapes', 'shaping']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['interpose', 'interposes', 'interposing']
# ['resets', 'resetting']
# ['distribute', 'distributes', 'distributing']
# ['provide', 'provides', 'providing']
# ['give', 'gives', 'gave', 'given']
# ['wind', 'winds', 'wound']
# ['insert', 'inserts', 'inserting']
# ['move', 'moves', 'moved']
# ['insulate', 'insulates', 'insulating']
# ['thin', 'thins', 'thinned']
# ['reduces', 'reducing', 'reduced']
# ['could', "can't", "couldn't"]
# ['detect', 'detects', 'detecting']
# ['need', 'needs', 'needing', "needn't"]
# ['increase', 'increasing', 'increased']
# ['increase', 'increases', 'increased']
# ['produces', 'producing', 'produced']
# ['reduces', 'reducing', 'reduced']
# ['connects', 'connecting', 'connected']
# ['engage', 'engages', 'engaging']
# ['uses', 'using']
# ['generate', 'generates', 'generated']
# ['generates', 'generating', 'generated']
# ['uses', 'using']
# ['mean', 'meaning', 'meant']
# ['produces', 'producing', 'produced']
# ['mean', 'meaning', 'meant']
# ['uses', 'using']
# ['haul', 'hauls', 'hauled']
# ['adapt', 'adapts', 'adapting']
# ['relate', 'relating', 'related']
# ['comprise', 'comprising', 'comprised']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['defines', 'defining', 'defined']
# ['mount', 'mounts', 'mounting']
# ['adjust', 'adjusts', 'adjusted']
# ['could', "can't", "couldn't"]
# ['adjust', 'adjusts', 'adjusted']
# ['vary', 'varies', 'varying']
# ['adapts', 'adapting', 'adapted']
# ['provide', 'provides', 'providing']
# ['say', 'says', 'saying']
# ['say', 'says', 'saying']
# ['prevail', 'prevails', 'prevailed']
# ['convert', 'converts', 'converting']
# ['could', "can't", "couldn't"]
# ['adjust', 'adjusts', 'adjusted']
# ['provide', 'provides', 'provided']
# ['eliminate', 'eliminates', 'eliminated']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['used', 'using']
# ['connect', 'connects', 'connecting']
# ['filters', 'filtering', 'filtered']
# ['include', 'including', 'included']
# ['plays', 'playing', 'played']
# ['output', 'outputs', 'outputted']
# ['change', 'changes', 'changed']
# ['stops', 'stopping', 'stopped']
# ['generates', 'generating', 'generated']
# ['dry', 'dries', 'dried']
# ['provide', 'provides', 'providing']
# ['provide', 'provides', 'providing']
# ['permit', 'permits', 'permitting']
# ['comprise', 'comprising', 'comprised']
# ['form', 'forms', 'forming']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['mount', 'mounts', 'mounting']
# ['oppose', 'opposing', 'opposed']
# ['holds', 'holding', 'held']
# ['protrudes', 'protruding', 'protruded']
# ['arrange', 'arranges', 'arranging']
# ['concern', 'concerning', 'concerned']
# ['used', 'uses']
# ['posit', 'posits', 'posited']
# ['reduce', 'reduces', 'reduced']
# ['facilitates', 'facilitating', 'facilitated']
# ['atomize', 'atomizes', 'atomized']
# ['supply', 'supplies', 'supplied']
# ['operate', 'operates', 'operated']
# ['reduce', 'reduces', 'reduced']
# ['define', 'defines', 'defining']
# ['introduce', 'introduces', 'introducing']
# ['select', 'selects', 'selecting']
# ['makes', 'making', 'made']
# ['comprise', 'comprising', 'comprised']
# ['result', 'results', 'resulted']
# ['contain', 'contains', 'contained']
# ['dedust', 'dedusts', 'dedusted']
# ['contain', 'contains', 'contained']
# ['empty', 'empties', 'emptying']
# ['condense', 'condenses', 'condensing']
# ['uses', 'using']
# ['subject', 'subjects', 'subjecting']
# ['modify', 'modifies', 'modifying']
# ['wastes', 'wasting', 'wasted']
# ['contain', 'contains', 'contained']
# ['provide', 'provides', 'provided']
# ['provide', 'provides', 'providing']
# ['cool', 'cools', 'cooled']
# ['cool', 'cools', 'cooled']
# ['house', 'houses', 'housing']
# ['include', 'including', 'included']
# ['include', 'including', 'included']
# ['alternate', 'alternates', 'alternated']
# ['receive', 'receives', 'received']
# ['separates', 'separating', 'separated']
# ['perform', 'performs', 'performed']
# ['re-cover', 're-covers', 're-covering', 're-covered']
# ['impurity', 'impuritying', 'impuritied']
# ['provide', 'provides', 'providing']
# ['separates', 'separating', 'separated']
# ['reduce', 'reduces', 'reduced']
# ['contain', 'contains', 'contained']
# ['include', 'including', 'included']
# ['allow', 'allows', 'allowed']
# ['enhance', 'enhances', 'enhanced']
# ['range', 'ranges', 'ranged']
# ['range', 'ranges', 'ranged']
# ['transmit', 'transmits', 'transmitting']
# ['range', 'ranges', 'ranged']
# ['range', 'ranges', 'ranged']
# ['superimpose', 'superimposes', 'superimposing']
# ['range', 'ranges', 'ranged']
# ['range', 'ranges', 'ranged']
# ['test', 'tests', 'testing']
# ['includes', 'including', 'included']
# ['become', 'becoming', 'became']
# ['mix', 'mixes', 'mixed']
# ['fit', 'fits', 'fitted']
# ['separate', 'separates', 'separating']
# ['include', 'including', 'included']
# ['retain', 'retains', 'retaining']
# ['extracts', 'extracting', 'extracted']
# ['mayest', "mayn't"]
# ['mayest', "mayn't"]
# ['allow', 'allowing', 'allowed']
# ['insert', 'inserts', 'inserted']
# ['mayest', "mayn't"]
# ['mayest', "mayn't"]
# ['collect', 'collects', 'collecting']
# ['compress', 'compresses', 'compressing']
# ['includes', 'including', 'included']
# ['uses', 'using']
# ['mixes', 'mixing', 'mixed']
# ['conduct', 'conducts', 'conducted']
# ['press', 'presses', 'pressed']
# ['include', 'including', 'included']
# ['retain', 'retains', 'retaining']
# ['conduct', 'conducts', 'conducted']
# ['mayest', "mayn't"]
# ['mixes', 'mixing', 'mixed']
# ['identify', 'identifies', 'identified']
# ['connect', 'connects', 'connecting']
# ['relate', 'relates', 'related']
# ['determine', 'determines', 'determined']
# ['originate', 'originates', 'originating']
# ['originate', 'originates', 'originated']
# ['call', 'calling', 'called']
# ['map', 'maps', 'mapped']
# ['direct', 'directs', 'directed']
# ['rout', 'routs', 'routing']
# ['receive', 'receives', 'received']
# ['redirect', 'redirects', 'redirected']
# ['presensitize', 'presensitizes', 'presensitizing']
# ['pass', 'passes', 'passed']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['provide', 'provides', 'providing']
# ['extend', 'extending', 'extended']
# ['comprise', 'comprises', 'comprised']
# ['align', 'aligns', 'aligning']
# ['dissipate', 'dissipates', 'dissipated']
# ['mean', 'meaning', 'meant']
# ['provide', 'provides', 'providing']
# ['relate', 'relating', 'related']
# ['papermake', 'papermakes', 'papermaked']
# ['connect', 'connecting', 'connected']
# ['could', "can't", "couldn't"]
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['depict', 'depicting', 'depicted']
# ['relate', 'relating', 'related']
# ['comprise', 'comprises', 'comprising']
# ['receive', 'receiving', 'received']
# ['say', 'says', 'saying']
# ['form', 'forms', 'formed']
# ['enhance', 'enhances', 'enhancing']
# ['weave', 'weaves', 'weaving', 'wove']
# ['include', 'including', 'included']
# ['mount', 'mounts', 'mounting']
# ['adapt', 'adapts', 'adapting']
# ['mount', 'mounts', 'mounting']
# ['communicate', 'communicates', 'communicating']
# ['include', 'including', 'included']
# ['place', 'places', 'placing']
# ['include', 'includes', 'included']
# ['prevent', 'prevents', 'prevented']
# ['say', 'says', 'saying']
# ['comprise', 'comprises', 'comprised']
# ['associate', 'associates', 'associating']
# ['separate', 'separates', 'separated']
# ['propose', 'proposes', 'proposing']
# ['maintains', 'maintaining', 'maintained']
# ['communicate', 'communicates', 'communicated']
# ['synchronize', 'synchronizes', 'synchronized']
# ['base', 'bases', 'basing']
# ['optimize', 'optimizes', 'optimizing']
# ['change', 'changes', 'changed']
# ['provide', 'provides', 'providing']
# ['sense', 'senses', 'sensed']
# ['identify', 'identifies', 'identified']
# ['include', 'including', 'included']
# ['provide', 'provides', 'providing']
# ['switch', 'switches', 'switched']
# ['consist', 'consisting', 'consisted']
# ['mix', 'mixes', 'mixed']
# ['inject', 'injects', 'injected']
# ['act', 'acting', 'acted']
# ['discharge', 'discharges', 'discharging']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['occur', 'occurring', 'occurred']
# ['allow', 'allows', 'allowed']
# ['passes', 'passing', 'passed']
# ['position', 'positions', 'positioning']
# ['pass', 'passes', 'passed']
# ['dispose', 'disposes', 'disposing']
# ['mix', 'mixes', 'mixed']
# ['mix', 'mixes', 'mixed']
# ['prevents', 'preventing', 'prevented']
# ['defines', 'defining', 'defined']
# ['compose', 'composes', 'composing']
# ['adapt', 'adapts', 'adapted']
# ['adapt', 'adapts', 'adapting']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['glaze', 'glazes', 'glazed']
# ['define', 'defines', 'defining']
# ['includes', 'including', 'included']
# ['remove', 'removes', 'removed']
# ['destroy', 'destroys', 'destroyed']
# ['frame', 'frames', 'framed']
# ['define', 'defines', 'defining']
# ['join', 'joins', 'joining']
# ['mayest', "mayn't"]
# ['employ', 'employs', 'employing']
# ['accomplish', 'accomplishes', 'accomplishing']
# ['minimizes', 'minimizing', 'minimized']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['construct', 'constructs', 'constructing']
# ['permits', 'permitting', 'permitted']
# ['weld', 'welds', 'welded']
# ['orient', 'orients', 'oriented']
# ['communicate', 'communicates', 'communicated']
# ['seal', 'seals', 'sealed']
# ['receives', 'receiving', 'received']
# ['provide', 'provides', 'providing']
# ['bias', 'biases', 'biassing', 'biassed']
# ['comprise', 'comprising', 'comprised']
# ['telescope', 'telescopes', 'telescoped']
# ['attach', 'attaching', 'attached']
# ['allow', 'allowing', 'allowed']
# ['define', 'defining', 'defined']
# ['say', 'says', 'saying']
# ['implement', 'implements', 'implementing']
# ['assign', 'assigns', 'assigned']
# ['derive', 'derives', 'derived']
# ['obtain', 'obtains', 'obtaining']
# ['evaluate', 'evaluates', 'evaluated']
# ['amend', 'amends', 'amended']
# ['transmit', 'transmits', 'transmitted']
# ['evaluate', 'evaluates', 'evaluated']
# ['intercept', 'intercepts', 'intercepted']
# ['locate', 'locates', 'locating']
# ['impose', 'imposes', 'imposed']
# ['form', 'forms', 'forming']
# ['locate', 'locates', 'locating']
# ['take', 'takes', 'taking', 'took']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['join', 'joins', 'joining']
# ['lift', 'lifting', 'lifted']
# ['overrides', 'overriding', 'overrode', 'overridden']
# ['say', 'says', 'saying']
# ['lift', 'lifts', 'lifted']
# ['mayest', "mayn't"]
# ['permits', 'permitting', 'permitted']
# ['say', 'says', 'saying']
# ['mayest', "mayn't"]
# ['inhibit', 'inhibiting', 'inhibited']
# ['senses', 'sensing', 'sensed']
# ['operate', 'operates', 'operating']
# ['operate', 'operates', 'operating']
# ['say', 'says', 'saying']
# ['limit', 'limiting', 'limited']
# ['lift', 'lifts', 'lifted']
# ['prevents', 'preventing', 'prevented']
# ['relate', 'relating', 'related']
# ['relate', 'relating', 'related']
# ['utilize', 'utilizes', 'utilizing']
# ['immunoglobulins', 'immunoglobulinning', 'immunoglobulinned']
# ['provide', 'provides', 'providing']
# ['provide', 'provides', 'providing']
# ['comprise', 'comprises', 'comprised']
# ['process', 'processes', 'processing']
# ['segment', 'segments', 'segmented']
# ['slits', 'slitting']
# ['direct', 'directs', 'directing']
# ['make', 'makes', 'made']
# ['telescope', 'telescopes', 'telescoped']
# ['cut', 'cuts']
# ['direct', 'directs', 'directing']
# ['permit', 'permits', 'permitted']
# ['overlap', 'overlaps', 'overlapped']
# ['form', 'forms', 'forming']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['surround', 'surrounds', 'surrounded']
# ['contain', 'contains', 'containing']
# ['comprise', 'comprising', 'comprised']
# ['configure', 'configures', 'configuring']
# ['say', 'says', 'saying']
# ['includes', 'including', 'included']
# ['locate', 'locates', 'locating']
# ['limits', 'limiting', 'limited']
# ['say', 'says', 'saying']
# ['mayest', "mayn't"]
# ['give', 'gives', 'giving', 'gave']
# ['say', 'says', 'saying']
# ['desire', 'desires', 'desiring']
# ['control', 'controls', 'controlling']
# ['defines', 'defining', 'defined']
# ['measure', 'measures', 'measuring']
# ['intend', 'intends', 'intending']
# ['disclose', 'discloses', 'disclosing']
# ['increase', 'increases', 'increasing']
# ['specifies', 'specifying', 'specified']
# ['include', 'includes', 'included']
# ['uses', 'using']
# ['suppose', 'supposes', 'supposing']
# ['disclose', 'discloses', 'disclosing']
# ['clon', 'clons', 'clonning', 'clonned']
# ['obtain', 'obtains', 'obtaining']
# ['designate', 'designates', 'designating']
# ['infect', 'infects', 'infecting']
# ['uses', 'using']
# ['call', 'calls', 'calling']
# ['woulds', 'woulding', 'woulded', "wouldn't"]
# ['avoid', 'avoids', 'avoiding']
# ['establish', 'establishes', 'establishing']
# ['minimize', 'minimizes', 'minimized']
# ['uses', 'using']
# ['shoulds', 'shoulding', 'shoulded', "shouldn't"]
# ['implement', 'implements', 'implementing']
# ['call', 'calls', 'called']
# ['identify', 'identifies', 'identifying']
# ['integrate', 'integrates', 'integrating']
# ['comprise', 'comprising', 'comprised']
# ['move', 'moves', 'moved']
# ['prevents', 'preventing', 'prevented']
# ['set', 'sets']
# ['bar', 'barring', 'barred']
# ['reduce', 'reduces', 'reducing']
# ['slip', 'slipping', 'slipped']
# ['mayest', "mayn't"]
# ['link', 'linking', 'linked']
# ['dispose', 'disposes', 'disposing']
# ['adjust', 'adjusts', 'adjusting']
# ['could', "can't", "couldn't"]
# ['dispose', 'disposes', 'disposing']
# ['associate', 'associates', 'associating']
# ['maintains', 'maintaining', 'maintained']
# ['cause', 'causes', 'caused']
# ['mandrels', 'mandrelling', 'mandrelled']
# ['mount', 'mounts', 'mounting']
# ['telescope', 'telescopes', 'telescoping']
# ['mount', 'mounts', 'mounting']
# ['bias', 'biases', 'biassed']
# ['store', 'stores', 'storing']
# ['used', 'using']
# ['disclose', 'discloses', 'disclosed']
# ['disclose', 'discloses', 'disclosed']
# ['approximate', 'approximating', 'approximated']
# ['produce', 'produces', 'producing']
# ['add', 'adds', 'adding']
# ['float', 'floats', 'floated']
# ['round', 'rounds', 'rounded']
# ['perform', 'performs', 'performing']
# ['include', 'including', 'included']
# ['include', 'includes', 'included']
# ['dispose', 'disposes', 'disposing']
# ['provide', 'provides', 'providing']
# ['post', 'posts', 'posting']
# ['assist', 'assists', 'assisting']
# ['uses', 'using']
# ['disassociate', 'disassociating', 'disassociated']
# ['smooth', 'smooths', 'smoothed']
# ['retain', 'retains', 'retained']
# ['provide', 'provides', 'providing']
# ['switch', 'switches', 'switched']
# ['change', 'changes', 'changing']
# ['switch', 'switches', 'switching']
# ['control', 'controls', 'controlling']
# ['contain', 'containing', 'contained']
# ['provide', 'provides', 'providing']
# ['provides', 'providing', 'provided']
# ['reduces', 'reducing', 'reduced']
# ['uses', 'using']
# ['modify', 'modifies', 'modifying']
# ['include', 'including', 'included']
# ['include', 'including', 'included']
# ['block', 'blocks', 'blocked']
# ['identify', 'identifies', 'identified']
# ['include', 'including', 'included']
# ['mayest', "mayn't"]
# ['predetermine', 'predetermines', 'predetermining']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['include', 'including', 'included']
# ['monitor', 'monitors', 'monitored']
# ['reduce', 'reduces', 'reducing']
# ['determine', 'determines', 'determined']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['comprise', 'comprising', 'comprised']
# ['reduce', 'reduces', 'reduced']
# ['control', 'controlling', 'controlled']
# ['reduce', 'reducing', 'reduced']
# ['includes', 'including', 'included']
# ['include', 'includes', 'included']
# ['communicate', 'communicates', 'communicated']
# ['construct', 'constructs', 'constructing']
# ['contacts', 'contacting', 'contacted']
# ['include', 'includes', 'including']
# ['includes', 'including', 'included']
# ['include', 'including', 'included']
# ['include', 'including', 'included']
# ['mayest', "mayn't"]
# ['arrange', 'arranges', 'arranging']
# ['arrange', 'arranges', 'arranging']
# ['acquires', 'acquiring', 'acquired']
# ['detect', 'detects', 'detected']
# ['generates', 'generating', 'generated']
# ['acquire', 'acquires', 'acquired']
# ['mount', 'mounts', 'mounting']
# ['dispense', 'dispenses', 'dispensed']
# ['dispense', 'dispenses', 'dispensed']
# ['secures', 'securing', 'secured']
# ['configure', 'configures', 'configuring']
# ['secures', 'securing', 'secured']
# ['comprise', 'comprising', 'comprised']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['include', 'including', 'included']
# ['secures', 'securing', 'secured']
# ['serve', 'serving', 'served']
# ['connect', 'connects', 'connected']
# ['interlock', 'interlocks', 'interlocked']
# ['connect', 'connects', 'connected']
# ['project', 'projects', 'projected']
# ['undergo', 'undergoes', 'underwent', 'undergone']
# ['divide', 'divides', 'dividing']
# ['seal', 'seals', 'sealed']
# ['facilitate', 'facilitating', 'facilitated']
# ['achieves', 'achieving', 'achieved']
# ['project', 'projects', 'projecting']
# ['desire', 'desires', 'desiring']
# ['polish', 'polishes', 'polished']
# ['uses', 'using']
# ['apply', 'applies', 'applying']
# ['used', 'using']
# ['calculate', 'calculates', 'calculating']
# ['used', 'uses']
# ['figure', 'figures', 'figured']
# ['performs', 'performing', 'performed']
# ['improve', 'improves', 'improved']
# ['mayest', "mayn't"]
# ['receives', 'receiving', 'received']
# ['provide', 'provides', 'provided']
# ['stands', 'standing', 'stood']
# ['performs', 'performing', 'performed']
# ['enables', 'enabling', 'enabled']
# ['could', "can't", "couldn't"]
# ['comprise', 'comprises', 'comprised']
# ['associate', 'associates', 'associating']
# ['include', 'includes', 'included']
# ['adapt', 'adapts', 'adapting']
# ['impart', 'imparts', 'imparted']
# ['comprise', 'comprising', 'comprised']
# ['coat', 'coats', 'coating']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['relate', 'relating', 'related']
# ['control', 'controls', 'controlling']
# ['accord', 'accords', 'accorded']
# ['used', 'uses']
# ['spreads', 'spreading']
# ['give', 'giving', 'gave', 'given']
# ['dry', 'dries', 'drying']
# ['forms', 'forming', 'formed']
# ['reduce', 'reduces', 'reduced']
# ['performs', 'performing', 'performed']
# ['include', 'includes', 'included']
# ['prevent', 'prevents', 'preventing']
# ['stick', 'sticks', 'stuck']
# ['combine', 'combines', 'combined']
# ['illuminate', 'illuminates', 'illuminated']
# ['act', 'acts', 'acted']
# ['collimates', 'collimating', 'collimated']
# ['come', 'comes', 'came']
# ['aim', 'aims', 'aiming']
# ['relate', 'relating', 'related']
# ['comprise', 'comprising', 'comprised']
# ['indicate', 'indicates', 'indicated']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['comprise', 'comprises', 'comprised']
# ['generate', 'generates', 'generating']
# ['projects', 'projecting', 'projected']
# ['assemble', 'assembles', 'assembled']
# ['place', 'places', 'placing']
# ['say', 'says', 'saying']
# ['contain', 'contains', 'contained']
# ['determine', 'determines', 'determined']
# ['base', 'bases', 'basing']
# ['include', 'including', 'included']
# ['attach', 'attaches', 'attaching']
# ['include', 'includes', 'included']
# ['close', 'closes', 'closing']
# ['indicate', 'indicates', 'indicated']
# ['say', 'says', 'saying']
# ['could', "can't", "couldn't"]
# ['integrate', 'integrates', 'integrating']
# ['include', 'including', 'included']
# ['cause', 'causing', 'caused']
# ['pull', 'pulls', 'pulling']
# ['attach', 'attaches', 'attaching']
# ['weave', 'weaves', 'weaving', 'wove']
# ['parachutes', 'parachuting', 'parachuted']
# ['dissipate', 'dissipates', 'dissipated']
# ['pull', 'pulls', 'pulling']
# ['breaks', 'breaking', 'broke', 'broken']
# ['accelerate', 'accelerates', 'accelerating']
# ['prepare', 'prepares', 'preparing']
# ['include', 'includes', 'included']
# ['synthesize', 'synthesizes', 'synthesized']
# ['novels', 'novelling', 'novelled']
# ['photoregulate', 'photoregulates', 'photoregulating']
# ['functionalize', 'functionalizes', 'functionalizing']
# ['couple', 'couples', 'coupling']
# ['base', 'bases', 'basing']
# ['provides', 'providing', 'provided']
# ['include', 'including', 'included']
# ['configure', 'configures', 'configuring']
# ['correspond', 'corresponds', 'corresponded']
# ['contain', 'contains', 'contained']
# ['configure', 'configures', 'configuring']
# ['rigidify', 'rigidifies', 'rigidified']
# ['secure', 'secures', 'securing']
# ['place', 'places', 'placing']
# ['liquefy', 'liquefies', 'liquefying']
# ['weave', 'weaves', 'weaving', 'wove']
# ['interweave', 'interweaves', 'interweaving', 'interwove']
# ['disclose', 'discloses', 'disclosing']
# ['comprise', 'comprises', 'comprised']
# ['provide', 'provides', 'providing']
# ['operate', 'operating', 'operated']
# ['provide', 'providing', 'provided']
# ['predetermine', 'predetermines', 'predetermining']
# ['predetermine', 'predetermines', 'predetermining']
# ['occur', 'occurs', 'occurring']
# ['inject', 'injects', 'injected']
# ['produces', 'producing', 'produced']
# ['hydrogenates', 'hydrogenating', 'hydrogenated']
# ['reduce', 'reduces', 'reducing']
# ['allows', 'allowing', 'allowed']
# ['flows', 'flowing', 'flowed']
# ['upgrade', 'upgrades', 'upgrading']
# ['increases', 'increasing', 'increased']
# ['direct', 'directs', 'directing']
# ['space', 'spaces', 'spacing']
# ['include', 'including', 'included']
# ['rub', 'rubs', 'rubbed']
# ['distribute', 'distributes', 'distributing']
# ['permits', 'permitting', 'permitted']
# ['rub', 'rubs', 'rubbed']
# ['trigger', 'triggers', 'triggering']
# ['isolate', 'isolates', 'isolating']
# ['utilize', 'utilizing', 'utilized']
# ['mount', 'mounts', 'mounted']
# ['protrude', 'protrudes', 'protruded']
# ['contain', 'containing', 'contained']
# ['embed', 'embeds', 'embedding']
# ['embed', 'embeds', 'embedding']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['stresses', 'stressing', 'stressed']
# ['fold', 'folding', 'folded']
# ['cuts', 'cutting']
# ['shim', 'shims', 'shimmed']
# ['prepare', 'prepares', 'prepared']
# ['cause', 'causing', 'caused']
# ['arrange', 'arranges', 'arranging']
# ['circulate', 'circulates', 'circulated']
# ['include', 'including', 'included']
# ['contour', 'contours', 'contouring']
# ['rescues', 'rescuing', 'rescued']
# ['inflame', 'inflames', 'inflaming']
# ['transport', 'transports', 'transporting']
# ['keep', 'keeps', 'keeping']
# ['incapacitate', 'incapacitates', 'incapacitating']
# ['accommodates', 'accommodating', 'accommodated']
# ['incapacitate', 'incapacitates', 'incapacitating']
# ['straddle', 'straddling', 'straddled']
# ['differentiates', 'differentiating', 'differentiated']
# ['base', 'bases', 'basing']
# ['inhibit', 'inhibits', 'inhibited']
# ['normalizes', 'normalizing', 'normalized']
# ['induces', 'inducing', 'induced']
# ['overproduce', 'overproduces', 'overproduced']
# ['enhance', 'enhances', 'enhanced']
# ['provide', 'provides', 'providing']
# ['increases', 'increasing', 'increased']
# ['base', 'bases', 'basing']
# ['grows', 'growing', 'grew', 'grown']
# ['apply', 'applies', 'applying']
# ['play', 'playing', 'played']
# ['impose', 'imposes', 'imposing']
# ['secures', 'securing', 'secured']
# ['mount', 'mounts', 'mounted']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['engage', 'engages', 'engaged']
# ['mount', 'mounts', 'mounting']
# ['could', "can't", "couldn't"]
# ['engage', 'engages', 'engaged']
# ['rotate', 'rotates', 'rotated']
# ['could', "can't", "couldn't"]
# ['transmits', 'transmitting', 'transmitted']
# ['configure', 'configures', 'configuring']
# ['squibb', 'squibbs', 'squibbed']
# ['operate', 'operates', 'operated']
# ['desire', 'desires', 'desiring']
# ['require', 'requires', 'requiring']
# ['comprise', 'comprising', 'comprised']
# ['provides', 'providing', 'provided']
# ['facilitate', 'facilitating', 'facilitated']
# ['passes', 'passing', 'passed']
# ['provide', 'provides', 'providing']
# ['recover', 'recovers', 'recovered']
# ['set', 'sets']
# ['disturb', 'disturbs', 'disturbing']
# ['perform', 'performs', 'performing']
# ['secures', 'securing', 'secured']
# ['comprise', 'comprising', 'comprised']
# ['position', 'positions', 'positioned']
# ['extend', 'extending', 'extended']
# ['rotate', 'rotates', 'rotated']
# ['position', 'positions', 'positioned']
# ['secure', 'secures', 'securing']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['connect', 'connects', 'connected']
# ['mount', 'mounts', 'mounted']
# ['connect', 'connects', 'connected']
# ['rotate', 'rotates', 'rotated']
# ['connect', 'connects', 'connected']
# ['rotate', 'rotates', 'rotated']
# ['adapt', 'adapts', 'adapting']
# ['abut', 'abutting', 'abutted']
# ['abut', 'abutting', 'abutted']
# ['secure', 'secures', 'securing']
# ['increase', 'increases', 'increasing']
# ['become', 'becomes', 'became']
# ['receives', 'receiving', 'received']
# ['wrappeds', 'wrappeding', 'wrappeded']
# ['mount', 'mounts', 'mounting']
# ['remove', 'removes', 'removing']
# ['extract', 'extracts', 'extracting']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['bond', 'bonds', 'bonding']
# ['attach', 'attaches', 'attaching']
# ['include', 'including', 'included']
# ['shape', 'shapes', 'shaped']
# ['inject', 'injects', 'injecting']
# ['form', 'forms', 'forming']
# ['cure', 'cures', 'curing']
# ['form', 'forms', 'forming']
# ['manufacture', 'manufactures', 'manufacturing']
# ['requires', 'requiring', 'required']
# ['makes', 'making', 'made']
# ['uses', 'using']
# ['mount', 'mounts', 'mounting']
# ['regulate', 'regulates', 'regulating']
# ['trail', 'trails', 'trailed']
# ['urge', 'urges', 'urged']
# ['position', 'positions', 'positioning']
# ['advance', 'advances', 'advanced']
# ['provide', 'provides', 'providing']
# ['include', 'including', 'included']
# ['enter', 'entering', 'entered']
# ['urge', 'urges', 'urged']
# ['lead', 'leads', 'led']
# ['urge', 'urges', 'urged']
# ['form', 'forms', 'formed']
# ['relate', 'relating', 'related']
# ['inject', 'injects', 'injected']
# ['provide', 'provides', 'providing']
# ['transports', 'transporting', 'transported']
# ['stand', 'standing', 'stood']
# ['fix', 'fixes', 'fixing']
# ['fix', 'fixes', 'fixing']
# ['assign', 'assigns', 'assigning']
# ['travele', 'traveles', 'traveled']
# ['could', "can't", "couldn't"]
# ['position', 'positions', 'positioned']
# ['stand', 'standing', 'stood']
# ['could', "can't", "couldn't"]
# ['combine', 'combines', 'combining']
# ['process', 'processes', 'processed']
# ['could', "can't", "couldn't"]
# ['contain', 'contains', 'containing']
# ['position', 'positions', 'positioned']
# ['could', "can't", "couldn't"]
# ['could', "can't", "couldn't"]
# ['stand', 'standing', 'stood']
# ['include', 'including', 'included']
# ['maintains', 'maintaining', 'maintained']
# ['open', 'opens', 'opening']
# ['uses', 'using']
# ['facilitate', 'facilitates', 'facilitated']
# ['comprise', 'comprising', 'comprised']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['constrain', 'constrains', 'constraining']
# ['retracts', 'retracting', 'retracted']
# ['make', 'makes', 'made']
# ['compresses', 'compressing', 'compressed']
# ['cas', 'caing', 'caed']
# ['provide', 'providing', 'provided']
# ['select', 'selects', 'selecting']
# ['process', 'processes', 'processed']
# ['crimps', 'crimping', 'crimped']
# ['adjust', 'adjusts', 'adjusted']
# ['imparts', 'imparting', 'imparted']
# ['connect', 'connects', 'connecting']
# ['control', 'controls', 'controlling']
# ['performs', 'performing', 'performed']
# ['concern', 'concerns', 'concerned']
# ['provides', 'providing', 'provided']
# ['power', 'powers', 'powered']
# ['shears', 'shearing', 'sheared', 'shorn']
# ['fix', 'fixes', 'fixed']
# ['carry', 'carries', 'carried']
# ['include', 'including', 'included']
# ['fix', 'fixes', 'fixed']
# ['contact', 'contacts', 'contacted']
# ['result', 'results', 'resulting']
# ['vibrate', 'vibrates', 'vibrated']
# ['follow', 'follows', 'following']
# ['sides', 'siding', 'sided']
# ['allow', 'allowing', 'allowed']
# ['cause', 'causes', 'causing']
# ['sides', 'siding', 'sided']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['returns', 'returning', 'returned']
# ['input', 'inputs', 'inputting']
# ['define', 'defines', 'defined']
# ['include', 'includes', 'included']
# ['process', 'processes', 'processed']
# ['provide', 'providing', 'provided']
# ['oppose', 'opposes', 'opposed']
# ['generate', 'generates', 'generated']
# ['output', 'outputs', 'outputting']
# ['accord', 'accords', 'according']
# ['input', 'inputs', 'inputting']
# ['compute', 'computes', 'computed']
# ['process', 'processes', 'processed']
# ['compute', 'computes', 'computing']
# ['provide', 'provides', 'provided']
# ['initialize', 'initializes', 'initializing']
# ['output', 'outputs', 'outputting']
# ['allows', 'allowing', 'allowed']
# ['allow', 'allowing', 'allowed']
# ['initialize', 'initializes', 'initializing']
# ['verify', 'verifies', 'verifying']
# ['could', "can't", "couldn't"]
# ['could', "can't", "couldn't"]
# ['operate', 'operates', 'operated']
# ['obtain', 'obtains', 'obtaining']
# ['prevent', 'prevents', 'preventing']
# ['deforms', 'deforming', 'deformed']
# ['correspond', 'corresponds', 'corresponded']
# ['locate', 'locates', 'locating']
# ['control', 'controls', 'controlled']
# ['casts', 'casting']
# ['close', 'closing', 'closed']
# ['uses', 'using']
# ['prevents', 'preventing', 'prevented']
# ['reduces', 'reducing', 'reduced']
# ['tailor', 'tailors', 'tailoring']
# ['provide', 'provides', 'providing']
# ['uses', 'using']
# ['associate', 'associates', 'associating']
# ['control', 'controls', 'controlled']
# ['space', 'spaces', 'spacing']
# ['arrange', 'arranges', 'arranging']
# ['produces', 'producing', 'produced']
# ['couple', 'couples', 'coupled']
# ['actuates', 'actuating', 'actuated']
# ['include', 'including', 'included']
# ['configure', 'configures', 'configuring']
# ['align', 'aligns', 'aligning']
# ['dispose', 'disposes', 'disposing']
# ['actuates', 'actuating', 'actuated']
# ['actuate', 'actuating', 'actuated']
# ['include', 'includes', 'including']
# ['conduct', 'conducts', 'conducting']
# ['stick', 'sticks', 'sticking']
# ['position', 'positions', 'positioning']
# ['differ', 'differs', 'differed']
# ['receive', 'receives', 'received']
# ['provide', 'provides', 'providing']
# ['position', 'positions', 'positioning']
# ['provide', 'provides', 'providing']
# ['include', 'including', 'included']
# ['biases', 'biassing', 'biassed']
# ['controls', 'controlling', 'controlled']
# ['correspond', 'corresponds', 'corresponded']
# ['lands', 'landing', 'landed']
# ['mirror', 'mirroring', 'mirrored']
# ['include', 'including', 'included']
# ['permits', 'permitting', 'permitted']
# ['measure', 'measures', 'measuring']
# ['mount', 'mounts', 'mounting']
# ['uses', 'using']
# ['control', 'controlling', 'controlled']
# ['molds', 'molding', 'molded']
# ['discharge', 'discharges', 'discharged']
# ['make', 'makes', 'making']
# ['pack', 'packs', 'packing']
# ['crack', 'cracks', 'cracked']
# ['produces', 'producing', 'produced']
# ['increase', 'increases', 'increasing']
# ['give', 'gives', 'giving', 'gave']
# ['reduce', 'reduces', 'reduced']
# ['detect', 'detects', 'detected']
# ['produce', 'producing', 'produced']
# ['fall', 'falls', 'fell', 'fallen']
# ['willing', 'willed', "won't"]
# ['reduce', 'reduces', 'reduced']
# ['used', 'uses']
# ['cas', 'caing', 'caed']
# ['need', 'needs', 'needed', "needn't"]
# ['could', "can't", "couldn't"]
# ['include', 'including', 'included']
# ['follow', 'follows', 'followed']
# ['obtain', 'obtains', 'obtained']
# ['form', 'forms', 'forming']
# ['modify', 'modifies', 'modifying']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['forms', 'forming', 'formed']
# ['heat', 'heats', 'het']
# ['coat', 'coats', 'coating']
# ['prepare', 'prepares', 'preparing']
# ['modify', 'modifies', 'modifying']
# ['substitute', 'substitutes', 'substituting']
# ['develop', 'develops', 'developing']
# ['transferrr', 'transferrrs', 'transferrred']
# ['transfer', 'transfers', 'transferred']
# ['reduce', 'reduces', 'reduced']
# ['increase', 'increases', 'increasing']
# ['reduces', 'reducing', 'reduced']
# ['define', 'defines', 'defining']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['defines', 'defining', 'defined']
# ['lie', 'lies', 'lied']
# ['provide', 'provides', 'providing']
# ['provide', 'provides', 'providing']
# ['telescope', 'telescopes', 'telescoped']
# ['determines', 'determining', 'determined']
# ['extend', 'extends', 'extended']
# ['rotates', 'rotating', 'rotated']
# ['control', 'controls', 'controlled']
# ['form', 'forms', 'forming']
# ['provides', 'providing', 'provided']
# ['trail', 'trails', 'trailed']
# ['mount', 'mounts', 'mounting']
# ['induces', 'inducing', 'induced']
# ['lead', 'leads', 'led']
# ['trail', 'trails', 'trailed']
# ['start', 'starts', 'started']
# ['correspond', 'corresponding', 'corresponded']
# ['defines', 'defining', 'defined']
# ['lead', 'leads', 'led']
# ['occupy', 'occupying', 'occupied']
# ['disclose', 'discloses', 'disclosing']
# ['provide', 'provides', 'provided']
# ['eats', 'eating', 'ate', 'eaten']
# ['provide', 'provides', 'providing']
# ['activate', 'activates', 'activating']
# ['produce', 'producing', 'produced']
# ['activate', 'activates', 'activating']
# ['swim', 'swims', 'swam', 'swum']
# ['retrieves', 'retrieving', 'retrieved']
# ['say', 'says', 'saying']
# ['say', 'says', 'saying']
# ['detect', 'detects', 'detecting']
# ['accord', 'accords', 'accorded']
# ['predetermine', 'predetermines', 'predetermining']
# ['correspond', 'corresponds', 'corresponded']
# ['multiplex', 'multiplexes', 'multiplexing']
# ['multiplex', 'multiplexes', 'multiplexing']
# ['correspond', 'corresponds', 'corresponded']
# ['say', 'says', 'saying']
# ['decompose', 'decomposes', 'decomposed']
# ['alkalines', 'alkalining', 'alkalined']
# ['deacidify', 'deacidifies', 'deacidified']
# ['treat', 'treats', 'treating']
# ['expose', 'exposes', 'exposing']
# ['treats', 'treating', 'treated']
# ['dry', 'dries', 'drying']
# ['define', 'defining', 'defined']
# ['comprise', 'comprises', 'comprised']
# ['could', "can't", "couldn't"]
# ['cover', 'covers', 'covered']
# ['creates', 'creating', 'created']
# ['create', 'creates', 'created']
# ['form', 'forms', 'forming']
# ['form', 'forms', 'forming']
# ['form', 'forms', 'forming']
# ['surrounds', 'surrounding', 'surrounded']
# ['insulate', 'insulates', 'insulated']
# ['control', 'controls', 'controlling']
# ['form', 'forms', 'forming']
# ['overlap', 'overlaps', 'overlapping']
# ['connect', 'connects', 'connecting']
# ['include', 'includes', 'included']
# ['overlap', 'overlaps', 'overlapping']
# ['overlap', 'overlaps', 'overlapped']
# ['include', 'including', 'included']
# ['insulate', 'insulates', 'insulated']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['include', 'including', 'included']
# ['include', 'including', 'included']
# ['cover', 'covers', 'covered']
# ['uses', 'using']
# ['preselect', 'preselects', 'preselecting']
# ['transmit', 'transmits', 'transmitted']
# ['connect', 'connects', 'connecting']
# ['connect', 'connects', 'connecting']
# ['inputs', 'inputting', 'inputted']
# ['uses', 'using']
# ['acertains', 'acertaining', 'acertained']
# ['changes', 'changing', 'changed']
# ['automate', 'automates', 'automating']
# ['include', 'includes', 'included']
# ['switch', 'switches', 'switched']
# ...
# ['provide', 'providing', 'provided']
# ['provides', 'providing', 'provided']
# ['fix', 'fixes', 'fixing']
# ['detect', 'detects', 'detected']
# ['allows', 'allowing', 'allowed']
# ['forms', 'forming', 'formed']
# ['prevents', 'preventing', 'prevented']
# ['comprise', 'comprising', 'comprised']
# ['couple', 'couples', 'coupling']
# ['detect', 'detects', 'detected']
# ['detect', 'detects', 'detected']
# ['comprise', 'comprises', 'comprised']
# ['combine', 'combines', 'combining']
# ['connects', 'connecting', 'connected']
# ['make', 'makes', 'making']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['establishes', 'establishing', 'established']
# ['exist', 'exists', 'existing']
# ['purpose', 'purposes', 'purposing']
# ['stick', 'sticks', 'sticking']
# ['travels', 'travelling', 'travelled']
# ['could', "can't", "couldn't"]
# ['determine', 'determines', 'determining']
# ['form', 'forms', 'forming']
# ['include', 'includes', 'including']
# ['knit', 'knits', 'knitting']
# ['provides', 'providing', 'provided']
# ['serve', 'serving', 'served']
# ['interlink', 'interlinks', 'interlinking']
# ['knit', 'knits', 'knitted']
# ['vaporize', 'vaporizes', 'vaporizing']
# ['obtain', 'obtains', 'obtaining']
# ['offer', 'offering', 'offered']
# ['strand', 'strands', 'stranding']
# ['insulate', 'insulates', 'insulated']
# ['space', 'spaces', 'spacing']
# ['mayest', "mayn't"]
# ['mount', 'mounts', 'mounting']
# ['cool', 'cools', 'cooled']
# ['describe', 'describes', 'describing']
# ['provide', 'provides', 'providing']
# ['expand', 'expands', 'expanding']
# ['mesh', 'meshs', 'meshing']
# ['contain', 'containing', 'contained']
# ['connect', 'connects', 'connecting']
# ['sort', 'sorts', 'sorted']
# ['stores', 'storing', 'stored']
# ['sort', 'sorts', 'sorted']
# ['include', 'including', 'included']
# ['predetermine', 'predetermines', 'predetermining']
# ['map', 'mapping', 'mapped']
# ['include', 'including', 'included']
# ['read', 'reads']
# ['represent', 'represents', 'represented']
# ['include', 'including', 'included']
# ['sort', 'sorting', 'sorted']
# ['selects', 'selecting', 'selected']
# ['transmit', 'transmits', 'transmitting']
# ['include', 'including', 'included']
# ['operate', 'operates', 'operating']
# ['support', 'supports', 'supporting']
# ['permit', 'permits', 'permitted']
# ['provide', 'provides', 'provided']
# ['include', 'includes', 'including']
# ['equip', 'equipping', 'equipped']
# ['exceeds', 'exceeding', 'exceeded']
# ['generate', 'generates', 'generated']
# ['direct', 'directing', 'directed']
# ['run', 'runs', 'ran']
# ['include', 'including', 'included']
# ['dewater', 'dewaters', 'dewaterring', 'dewaterred']
# ['carry', 'carries', 'carrying']
# ['remove', 'removes', 'removed']
# ['remove', 'removing', 'removed']
# ['includes', 'including', 'included']
# ['invert', 'inverts', 'inverting']
# ['subject', 'subjects', 'subjected']
# ['extend', 'extends', 'extending']
# ['prevent', 'prevents', 'prevented']
# ['adapt', 'adapts', 'adapted']
# ['result', 'results', 'resulted']
# ['select', 'selects', 'selecting']
# ['pulls', 'pulling', 'pulled']
# ['uses', 'using']
# ['pulls', 'pulling', 'pulled']
# ['tube', 'tubes', 'tubed']
# ['tube', 'tubes', 'tubed']
# ['retrieve', 'retrieves', 'retrieved']
# ['could', "can't", "couldn't"]
# ['automates', 'automating', 'automated']
# ['condense', 'condenses', 'condensing']
# ['print', 'prints', 'printing']
# ['uses', 'using']
# ['intend', 'intends', 'intending']
# ['sense', 'sensing', 'sensed']
# ['allow', 'allowing', 'allowed']
# ['remove', 'removes', 'removing']
# ['remove', 'removes', 'removing']
# ['passes', 'passing', 'passed']
# ['removes', 'removing', 'removed']
# ['evade', 'evades', 'evading']
# ['remove', 'removes', 'removed']
# ['affect', 'affecting', 'affected']
# ['prevent', 'prevents', 'prevented']
# ['provide', 'provides', 'providing']
# ['verifies', 'verifying', 'verified']
# ['adds', 'adding', 'added']
# ['include', 'including', 'included']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['transmit', 'transmits', 'transmitting']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['transmits', 'transmitting', 'transmitted']
# ['improves', 'improving', 'improved']
# ['include', 'includes', 'included']
# ['verify', 'verifies', 'verifying']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['forms', 'forming', 'formed']
# ['say', 'says', 'saying']
# ['micronize', 'micronizes', 'micronized']
# ['blend', 'blends', 'blended']
# ['form', 'forms', 'forming']
# ['separate', 'separates', 'separating']
# ['fold', 'folds', 'folding']
# ['uses', 'using']
# ['invert', 'inverts', 'inverting']
# ['falls', 'falling', 'fell', 'fallen']
# ['invert', 'inverts', 'inverting']
# ['capture', 'captures', 'capturing']
# ['define', 'defines', 'defined']
# ['pedicle', 'pedicling', 'pedicled']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['support', 'supports', 'supported']
# ['drops', 'dropping', 'dropped']
# ['separate', 'separates', 'separating']
# ['cause', 'causes', 'caused']
# ['pulp', 'pulps', 'pulped']
# ['dewire', 'dewires', 'dewired']
# ['improves', 'improving', 'improved']
# ['pulp', 'pulps', 'pulped']
# ['relate', 'relating', 'related']
# ['pulp', 'pulps', 'pulped']
# ['generates', 'generating', 'generated']
# ['contain', 'contains', 'contained']
# ['extend', 'extends', 'extended']
# ['produce', 'produces', 'produced']
# ['cover', 'covers', 'covering']
# ['faces', 'facing', 'faced']
# ['receive', 'receives', 'received']
# ['accord', 'accords', 'accorded']
# ['cut', 'cuts']
# ['cut', 'cuts']
# ['cut', 'cuts']
# ['relate', 'relating', 'related']
# ['fasten', 'fastens', 'fastened']
# ['compose', 'composes', 'composing']
# ['cover', 'covering', 'covered']
# ['forms', 'forming', 'formed']
# ['means', 'meaning', 'meant']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['reflect', 'reflects', 'reflecting']
# ['remains', 'remaining', 'remained']
# ['could', "can't", "couldn't"]
# ['can', "can't", "couldn't"]
# ['flip', 'flips', 'flipping']
# ['provide', 'provides', 'providing']
# ['compress', 'compresses', 'compressed']
# ['could', "can't", "couldn't"]
# ['connect', 'connects', 'connected']
# ['could', "can't", "couldn't"]
# ['uses', 'using']
# ['space', 'spaces', 'spacing']
# ['delays', 'delaying', 'delayed']
# ['stops', 'stopping', 'stopped']
# ['operate', 'operates', 'operated']
# ['provide', 'provides', 'providing']
# ['adjusts', 'adjusting', 'adjusted']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['adjust', 'adjusts', 'adjusted']
# ['control', 'controls', 'controlled']
# ['interpose', 'interposes', 'interposing']
# ['adjust', 'adjusts', 'adjusted']
# ['provide', 'provides', 'providing']
# ['include', 'including', 'included']
# ['provide', 'provides', 'providing']
# ['flush', 'flushes', 'flushed']
# ['urge', 'urging', 'urged']
# ['registers', 'registering', 'registered']
# ['used', 'uses']
# ['replace', 'replaces', 'replaced']
# ['provide', 'provides', 'providing']
# ['repair', 'repairs', 'repaired']
# ['include', 'including', 'included']
# ['join', 'joins', 'joined']
# ['connect', 'connects', 'connecting']
# ['become', 'becoming', 'became']
# ['repair', 'repairs', 'repaired']
# ['grip', 'grips', 'gript']
# ['holds', 'holding', 'held']
# ['monitor', 'monitors', 'monitored']
# ['carry', 'carries', 'carried']
# ['describe', 'describes', 'describing']
# ['provide', 'provides', 'provided']
# ['quantize', 'quantizing', 'quantized']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['include', 'including', 'included']
# ['scan', 'scanning', 'scanned']
# ['divide', 'divides', 'dividing']
# ['apply', 'applying', 'applied']
# ['code', 'codes', 'coded']
# ['produces', 'producing', 'produced']
# ['scan', 'scanning', 'scanned']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['connect', 'connects', 'connecting']
# ['piece', 'pieces', 'pieced']
# ['associate', 'associates', 'associating']
# ['dispose', 'disposes', 'disposing']
# ['wind', 'winds', 'wound']
# ['evaluate', 'evaluates', 'evaluating']
# ['vary', 'varies', 'varied']
# ['measure', 'measures', 'measuring']
# ['open', 'opens', 'opening']
# ['move', 'moves', 'moved']
# ['open', 'opens', 'opening']
# ['shape', 'shapes', 'shaping']
# ['smooth', 'smooths', 'smoothing']
# ['could', "can't", "couldn't"]
# ['vary', 'varies', 'varied']
# ['expand', 'expanding', 'expanded']
# ['supply', 'supplies', 'supplying']
# ['fix', 'fixes', 'fixed']
# ['group', 'groups', 'grouping']
# ['bear', 'bears', 'borne']
# ['comprise', 'comprising', 'comprised']
# ['mount', 'mounts', 'mounting']
# ['comprise', 'comprising', 'comprised']
# ['uses', 'using']
# ['end', 'ends', 'ending']
# ['allow', 'allowing', 'allowed']
# ['side', 'sides', 'siding']
# ['attach', 'attaches', 'attached']
# ['provides', 'providing', 'provided']
# ['damage', 'damages', 'damaging']
# ['abut', 'abuts', 'abutted']
# ['mayest', "mayn't"]
# ['attach', 'attaches', 'attaching']
# ['secure', 'secures', 'securing']
# ['mayest', "mayn't"]
# ['pierces', 'piercing', 'pierced']
# ['consist', 'consisting', 'consisted']
# ['uses', 'using']
# ['combine', 'combines', 'combining']
# ['apply', 'applies', 'applied']
# ['increase', 'increases', 'increased']
# ['apply', 'applies', 'applied']
# ['examine', 'examines', 'examining']
# ['observes', 'observing', 'observed']
# ['measure', 'measures', 'measured']
# ['place', 'places', 'placing']
# ['used', 'uses']
# ['observe', 'observes', 'observed']
# ['mayest', "mayn't"]
# ['desire', 'desires', 'desiring']
# ['prevent', 'preventing', 'prevented']
# ['provide', 'provides', 'providing']
# ['lead', 'leading', 'led']
# ['give', 'gives', 'giving', 'gave']
# ['give', 'gives', 'giving', 'gave']
# ['pass', 'passes', 'passed']
# ['form', 'forms', 'forming']
# ['define', 'defines', 'defining']
# ['guests', 'guesting', 'guested']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['include', 'includes', 'included']
# ['extend', 'extends', 'extended']
# ['position', 'positions', 'positioning']
# ['include', 'including', 'included']
# ['include', 'including', 'included']
# ['prevent', 'preventing', 'prevented']
# ['invert', 'inverts', 'inverting']
# ['allows', 'allowing', 'allowed']
# ['fall', 'falls', 'fell', 'fallen']
# ['enters', 'entering', 'entered']
# ['force', 'forces', 'forced']
# ['insert', 'inserts', 'inserting']
# ['constrains', 'constraining', 'constrained']
# ['mayest', "mayn't"]
# ['prevent', 'prevents', 'preventing']
# ['exits', 'exiting', 'exited']
# ['exits', 'exiting', 'exited']
# ['perform', 'performs', 'performed']
# ['include', 'including', 'included']
# ['fill', 'fills', 'filled']
# ['prevents', 'preventing', 'prevented']
# ['utilize', 'utilizing', 'utilized']
# ['assumes', 'assuming', 'assumed']
# ['move', 'moves', 'moved']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['connect', 'connects', 'connecting']
# ['generate', 'generates', 'generated']
# ['connect', 'connects', 'connecting']
# ['heats', 'heating', 'het']
# ['contract', 'contracts', 'contracting']
# ['select', 'selects', 'selecting']
# ['cause', 'causing', 'caused']
# ['utilize', 'utilizing', 'utilized']
# ['contract', 'contracts', 'contracting']
# ['memorize', 'memorizes', 'memorizing']
# ['retracts', 'retracting', 'retracted']
# ['allow', 'allows', 'allowed']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['retract', 'retracts', 'retracted']
# ['release', 'releases', 'releasing']
# ['design', 'designs', 'designing']
# ['cause', 'causing', 'caused']
# ['reverse', 'reverses', 'reversing']
# ['moves', 'moving', 'moved']
# ['supply', 'supplies', 'supplying']
# ['oscillate', 'oscillates', 'oscillated']
# ['supply', 'supplies', 'supplying']
# ['causes', 'causing', 'caused']
# ['supply', 'supplies', 'supplied']
# ['form', 'forms', 'formed']
# ['say', 'says', 'saying']
# ['operate', 'operates', 'operated']
# ['mean', 'meaning', 'meant']
# ['correspond', 'corresponds', 'corresponded']
# ['separate', 'separates', 'separating']
# ['causes', 'causing', 'caused']
# ['supply', 'supplies', 'supplying']
# ['filter', 'filters', 'filtered']
# ['carry', 'carries', 'carried']
# ['loops', 'looping', 'looped']
# ['operate', 'operates', 'operated']
# ['comprise', 'comprises', 'comprised']
# ['control', 'controls', 'controlling']
# ['supplies', 'supplying', 'supplied']
# ['supply', 'supplies', 'supplying']
# ['say', 'says', 'saying']
# ['amplify', 'amplifies', 'amplified']
# ['introduce', 'introduces', 'introducing']
# ['gives', 'giving', 'gave', 'given']
# ['contains', 'containing', 'contained']
# ['generate', 'generates', 'generated']
# ['introduce', 'introduces', 'introducing']
# ['could', "can't", "couldn't"]
# ['attaches', 'attaching', 'attached']
# ['code', 'codes', 'coding']
# ['display', 'displays', 'displayed']
# ['transmit', 'transmits', 'transmitting']
# ['provide', 'provides', 'providing']
# ['accompanies', 'accompanying', 'accompanied']
# ['react', 'reacts', 'reacting']
# ['separate', 'separates', 'separated']
# ['extend', 'extends', 'extended']
# ['include', 'including', 'included']
# ['connect', 'connects', 'connected']
# ['cut', 'cuts']
# ['stop', 'stops', 'stopped']
# ['cut', 'cuts']
# ['seals', 'sealing', 'sealed']
# ['form', 'forming', 'formed']
# ['provide', 'provides', 'provided']
# ['form', 'forms', 'forming']
# ['actuate', 'actuates', 'actuated']
# ['rotates', 'rotating', 'rotated']
# ['speak', 'speaks', 'speaking', 'spoken']
# ['release', 'releases', 'released']
# ['modify', 'modifies', 'modifying']
# ['accord', 'accords', 'accorded']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['describe', 'describes', 'describing']
# ['comprise', 'comprises', 'comprised']
# ['modify', 'modifies', 'modifying']
# ['contact', 'contacts', 'contacted']
# ['used', 'uses']
# ['comprise', 'comprises', 'comprised']
# ['mates', 'mating', 'mated']
# ['space', 'spaces', 'spacing']
# ['configure', 'configures', 'configuring']
# ['dispose', 'disposes', 'disposing']
# ['release', 'releases', 'released']
# ['dispose', 'disposes', 'disposing']
# ['permit', 'permitting', 'permitted']
# ['contain', 'containing', 'contained']
# ['pass', 'passing', 'passed']
# ['can', "can't", "couldn't"]
# ['improve', 'improves', 'improving']
# ['disclose', 'discloses', 'disclosing']
# ['mayest', "mayn't"]
# ['improve', 'improves', 'improving']
# ['fabricate', 'fabricates', 'fabricated']
# ['form', 'forms', 'forming']
# ['exhibit', 'exhibiting', 'exhibited']
# ['form', 'forms', 'formed']
# ['improve', 'improves', 'improving']
# ['improve', 'improves', 'improving']
# ['provide', 'providing', 'provided']
# ['disclose', 'discloses', 'disclosing']
# ['moves', 'moving', 'moved']
# ['place', 'places', 'placing']
# ['noises', 'noising', 'noised']
# ['improves', 'improving', 'improved']
# ['disclose', 'discloses', 'disclosed']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['improve', 'improves', 'improved']
# ['tighten', 'tightens', 'tightening']
# ['drive', 'drives', 'driving', 'drove']
# ['associate', 'associates', 'associated']
# ['detect', 'detects', 'detected']
# ['release', 'releases', 'released']
# ['predefine', 'predefines', 'predefining']
# ['release', 'releases', 'released']
# ['acts', 'acting', 'acted']
# ['authenticate', 'authenticates', 'authenticated']
# ['retrieve', 'retrieves', 'retrieving']
# ['request', 'requests', 'requested']
# ['apply', 'applies', 'applying']
# ['apply', 'applies', 'applying']
# ['randomize', 'randomizes', 'randomized']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['disclose', 'discloses', 'disclosing']
# ['include', 'including', 'included']
# ['address', 'addresses', 'addressing', 'addrest']
# ['form', 'forms', 'formed']
# ['fire', 'fires', 'fired']
# ['deposit', 'deposits', 'deposited']
# ['remove', 'removes', 'removed']
# ['include', 'including', 'included']
# ['absorb', 'absorbs', 'absorbing']
# ['achieve', 'achieves', 'achieved']
# ['connect', 'connects', 'connecting']
# ['form', 'forms', 'formed']
# ['say', 'says', 'saying']
# ['couple', 'couples', 'coupling']
# ['detect', 'detecting', 'detected']
# ['form', 'forms', 'forming']
# ['include', 'includes', 'included']
# ['identify', 'identifying', 'identified']
# ['uses', 'using']
# ['fork', 'forks', 'forking']
# ['support', 'supports', 'supported']
# ['contain', 'contains', 'contained']
# ['allow', 'allows', 'allowed']
# ['employ', 'employing', 'employed']
# ['erects', 'erecting', 'erected']
# ['form', 'forms', 'forming']
# ['contain', 'contains', 'contained']
# ['perfluorinate', 'perfluorinates', 'perfluorinating']
# ['uses', 'using']
# ['convert', 'converts', 'converting']
# ['contain', 'contains', 'contained']
# ['have', 'has', 'had', "haven't", "hasn't", "hadn't"]
# ['polymerize', 'polymerizes', 'polymerizing']
# ['advantages', 'advantaging', 'advantaged']
# ['comprise', 'comprises', 'comprised']

# %%
abstracts_random_indexes = np.random.randint(0,abstracts.shape[0],count)
print("Generating errors in ",len(abstracts_random_indexes)," documents.")
for i in abstracts_random_indexes:
  print("Introducing errors in document ",i)
  abstract_w_error = introduce_singular_plural_error(abstracts[i])
  abstracts[i] = abstract_w_error
  error_labels[i,1]=1
  error_labels[i,5]=1
# Out:
# Generating errors in  1113  documents.
# Introducing errors in document  419
# Introducing errors in document  1067
# Introducing errors in document  2921
# Introducing errors in document  3473
# Introducing errors in document  2302
# Introducing errors in document  403
# Introducing errors in document  2349
# Introducing errors in document  684
# Introducing errors in document  3694
# Introducing errors in document  3640
# Introducing errors in document  318
# Introducing errors in document  631
# Introducing errors in document  1716
# Introducing errors in document  3552
# Introducing errors in document  536
# Introducing errors in document  172
# Introducing errors in document  536
# Introducing errors in document  641
# Introducing errors in document  648
# Introducing errors in document  2449
# Introducing errors in document  1908
# Introducing errors in document  2584
# Introducing errors in document  3322
# Introducing errors in document  2744
# Introducing errors in document  105
# Introducing errors in document  1713
# Introducing errors in document  172
# Introducing errors in document  1515
# Introducing errors in document  2750
# Introducing errors in document  6
# Introducing errors in document  1605
# Introducing errors in document  2429
# Introducing errors in document  2868
# Introducing errors in document  934
# Introducing errors in document  1284
# Introducing errors in document  1988
# Introducing errors in document  3296
# Introducing errors in document  900
# Introducing errors in document  537
# Introducing errors in document  2775
# Introducing errors in document  18
# Introducing errors in document  937
# Introducing errors in document  1104
# Introducing errors in document  3500
# Introducing errors in document  3506
# Introducing errors in document  2943
# Introducing errors in document  3385
# Introducing errors in document  2346
# Introducing errors in document  1368
# Introducing errors in document  2360
# Introducing errors in document  1764
# Introducing errors in document  3290
# Introducing errors in document  280
# Introducing errors in document  2981
# Introducing errors in document  2548
# Introducing errors in document  2087
# Introducing errors in document  3642
# Introducing errors in document  1042
# Introducing errors in document  159
# Introducing errors in document  3205
# Introducing errors in document  270
# Introducing errors in document  3324
# Introducing errors in document  3623
# Introducing errors in document  2923
# Introducing errors in document  264
# Introducing errors in document  1816
# Introducing errors in document  2555
# Introducing errors in document  3309
# Introducing errors in document  3039
# Introducing errors in document  2042
# Introducing errors in document  1222
# Introducing errors in document  1838
# Introducing errors in document  2402
# Introducing errors in document  1616
# Introducing errors in document  2714
# Introducing errors in document  1682
# Introducing errors in document  3390
# Introducing errors in document  1551
# Introducing errors in document  1636
# Introducing errors in document  2203
# Introducing errors in document  2411
# Introducing errors in document  3280
# Introducing errors in document  3379
# Introducing errors in document  332
# Introducing errors in document  2004
# Introducing errors in document  1048
# Introducing errors in document  2970
# Introducing errors in document  1003
# Introducing errors in document  2144
# Introducing errors in document  2525
# Introducing errors in document  66
# Introducing errors in document  2846
# Introducing errors in document  955
# Introducing errors in document  2795
# Introducing errors in document  1222
# Introducing errors in document  1850
# Introducing errors in document  2502
# Introducing errors in document  3696
# Introducing errors in document  924
# Introducing errors in document  2522
# Introducing errors in document  3143
# Introducing errors in document  1613
# Introducing errors in document  3032
# Introducing errors in document  1898
# Introducing errors in document  1302
# Introducing errors in document  2727
# Introducing errors in document  564
# Introducing errors in document  2512
# Introducing errors in document  3171
# Introducing errors in document  695
# Introducing errors in document  2730
# Introducing errors in document  3417
# Introducing errors in document  3264
# Introducing errors in document  3476
# Introducing errors in document  2570
# Introducing errors in document  473
# Introducing errors in document  3106
# Introducing errors in document  1459
# Introducing errors in document  890
# Introducing errors in document  2126
# Introducing errors in document  2211
# Introducing errors in document  789
# Introducing errors in document  3265
# Introducing errors in document  2400
# Introducing errors in document  2411
# Introducing errors in document  2350
# Introducing errors in document  1469
# Introducing errors in document  1286
# Introducing errors in document  293
# Introducing errors in document  1270
# Introducing errors in document  3350
# Introducing errors in document  2935
# Introducing errors in document  2967
# Introducing errors in document  1951
# Introducing errors in document  3419
# Introducing errors in document  2002
# Introducing errors in document  2810
# Introducing errors in document  3183
# Introducing errors in document  3205
# Introducing errors in document  3134
# Introducing errors in document  2483
# Introducing errors in document  850
# Introducing errors in document  2867
# Introducing errors in document  667
# Introducing errors in document  2234
# Introducing errors in document  309
# Introducing errors in document  900
# Introducing errors in document  1938
# Introducing errors in document  1593
# Introducing errors in document  459
# Introducing errors in document  1771
# Introducing errors in document  2883
# Introducing errors in document  860
# Introducing errors in document  2389
# Introducing errors in document  836
# Introducing errors in document  183
# Introducing errors in document  1363
# Introducing errors in document  567
# Introducing errors in document  3494
# Introducing errors in document  2715
# Introducing errors in document  411
# Introducing errors in document  3070
# Introducing errors in document  3548
# Introducing errors in document  350
# Introducing errors in document  2627
# Introducing errors in document  2830
# Introducing errors in document  442
# Introducing errors in document  611
# Introducing errors in document  1158
# Introducing errors in document  1879
# Introducing errors in document  517
# Introducing errors in document  230
# Introducing errors in document  2793
# Introducing errors in document  3319
# Introducing errors in document  1864
# Introducing errors in document  1102
# Introducing errors in document  289
# Introducing errors in document  1572
# Introducing errors in document  3049
# Introducing errors in document  1487
# Introducing errors in document  3157
# Introducing errors in document  2347
# Introducing errors in document  2927
# Introducing errors in document  3371
# Introducing errors in document  2010
# Introducing errors in document  3591
# Introducing errors in document  1364
# Introducing errors in document  358
# Introducing errors in document  1953
# Introducing errors in document  278
# Introducing errors in document  3024
# Introducing errors in document  3544
# Introducing errors in document  242
# Introducing errors in document  1525
# Introducing errors in document  1693
# Introducing errors in document  15
# Introducing errors in document  412
# Introducing errors in document  1771
# Introducing errors in document  429
# Introducing errors in document  3034
# Introducing errors in document  2685
# Introducing errors in document  2986
# Introducing errors in document  2568
# Introducing errors in document  2963
# Introducing errors in document  3520
# Introducing errors in document  3601
# Introducing errors in document  981
# Introducing errors in document  71
# Introducing errors in document  2725
# Introducing errors in document  1362
# Introducing errors in document  1053
# Introducing errors in document  3111
# Introducing errors in document  2484
# Introducing errors in document  441
# Introducing errors in document  303
# Introducing errors in document  3637
# Introducing errors in document  3098
# Introducing errors in document  1308
# Introducing errors in document  2980
# Introducing errors in document  2765
# Introducing errors in document  1299
# Introducing errors in document  1594
# Introducing errors in document  1073
# Introducing errors in document  719
# Introducing errors in document  2766
# Introducing errors in document  1424
# Introducing errors in document  2247
# Introducing errors in document  3240
# Introducing errors in document  292
# Introducing errors in document  182
# Introducing errors in document  2861
# Introducing errors in document  3325
# Introducing errors in document  3524
# Introducing errors in document  2485
# Introducing errors in document  1807
# Introducing errors in document  3172
# Introducing errors in document  847
# Introducing errors in document  1806
# Introducing errors in document  2622
# Introducing errors in document  3600
# Introducing errors in document  3691
# Introducing errors in document  1544
# Introducing errors in document  2872
# Introducing errors in document  89
# Introducing errors in document  490
# Introducing errors in document  2714
# Introducing errors in document  1334
# Introducing errors in document  752
# Introducing errors in document  1407
# Introducing errors in document  1945
# Introducing errors in document  2957
# Introducing errors in document  3573
# Introducing errors in document  1571
# Introducing errors in document  689
# Introducing errors in document  1365
# Introducing errors in document  2017
# Introducing errors in document  31
# Introducing errors in document  3219
# Introducing errors in document  3690
# Introducing errors in document  1786
# Introducing errors in document  342
# Introducing errors in document  2820
# Introducing errors in document  3522
# Introducing errors in document  1636
# Introducing errors in document  3436
# Introducing errors in document  2820
# Introducing errors in document  2740
# Introducing errors in document  637
# Introducing errors in document  1027
# Introducing errors in document  3535
# Introducing errors in document  1823
# Introducing errors in document  3439
# Introducing errors in document  3403
# Introducing errors in document  3074
# Introducing errors in document  1041
# Introducing errors in document  3150
# Introducing errors in document  2394
# Introducing errors in document  3325
# Introducing errors in document  3478
# Introducing errors in document  3687
# Introducing errors in document  2104
# Introducing errors in document  2082
# Introducing errors in document  87
# Introducing errors in document  1494
# Introducing errors in document  2377
# Introducing errors in document  1500
# Introducing errors in document  2741
# Introducing errors in document  1222
# Introducing errors in document  2965
# Introducing errors in document  292
# Introducing errors in document  1530
# Introducing errors in document  3641
# Introducing errors in document  761
# Introducing errors in document  1634
# Introducing errors in document  3518
# Introducing errors in document  291
# Introducing errors in document  649
# Introducing errors in document  1739
# Introducing errors in document  587
# Introducing errors in document  2878
# Introducing errors in document  860
# Introducing errors in document  2506
# Introducing errors in document  2576
# Introducing errors in document  275
# Introducing errors in document  3475
# Introducing errors in document  160
# Introducing errors in document  2138
# Introducing errors in document  3558
# Introducing errors in document  2370
# Introducing errors in document  3673
# Introducing errors in document  758
# Introducing errors in document  2163
# Introducing errors in document  3502
# Introducing errors in document  927
# Introducing errors in document  883
# Introducing errors in document  400
# Introducing errors in document  2069
# Introducing errors in document  1874
# Introducing errors in document  1018
# Introducing errors in document  1514
# Introducing errors in document  2663
# Introducing errors in document  3531
# Introducing errors in document  2547
# Introducing errors in document  710
# Introducing errors in document  2052
# Introducing errors in document  1476
# Introducing errors in document  1065
# Introducing errors in document  1120
# Introducing errors in document  3535
# Introducing errors in document  3269
# Introducing errors in document  3129
# Introducing errors in document  3511
# Introducing errors in document  1436
# Introducing errors in document  3664
# Introducing errors in document  2157
# Introducing errors in document  2056
# Introducing errors in document  1745
# Introducing errors in document  797
# Introducing errors in document  3167
# Introducing errors in document  66
# Introducing errors in document  3615
# Introducing errors in document  2485
# Introducing errors in document  2792
# Introducing errors in document  3291
# Introducing errors in document  425
# Introducing errors in document  194
# Introducing errors in document  2726
# Introducing errors in document  1584
# Introducing errors in document  805
# Introducing errors in document  1147
# Introducing errors in document  3146
# Introducing errors in document  2809
# Introducing errors in document  3665
# Introducing errors in document  3379
# Introducing errors in document  697
# Introducing errors in document  3708
# Introducing errors in document  2805
# Introducing errors in document  1765
# Introducing errors in document  2734
# Introducing errors in document  486
# Introducing errors in document  1706
# Introducing errors in document  132
# Introducing errors in document  2006
# Introducing errors in document  588
# Introducing errors in document  2558
# Introducing errors in document  307
# Introducing errors in document  2174
# Introducing errors in document  2813
# Introducing errors in document  3184
# Introducing errors in document  1478
# Introducing errors in document  1185
# Introducing errors in document  181
# Introducing errors in document  734
# Introducing errors in document  848
# Introducing errors in document  3379
# Introducing errors in document  3533
# Introducing errors in document  2874
# Introducing errors in document  3268
# Introducing errors in document  904
# Introducing errors in document  703
# Introducing errors in document  317
# Introducing errors in document  383
# Introducing errors in document  2211
# Introducing errors in document  360
# Introducing errors in document  2270
# Introducing errors in document  1623
# Introducing errors in document  2256
# Introducing errors in document  3163
# Introducing errors in document  335
# Introducing errors in document  2258
# Introducing errors in document  1277
# Introducing errors in document  3350
# Introducing errors in document  1837
# Introducing errors in document  746
# Introducing errors in document  1306
# Introducing errors in document  324
# Introducing errors in document  2794
# Introducing errors in document  3609
# Introducing errors in document  2310
# Introducing errors in document  2125
# Introducing errors in document  111
# Introducing errors in document  1244
# Introducing errors in document  3200
# Introducing errors in document  2420
# Introducing errors in document  843
# Introducing errors in document  2229
# Introducing errors in document  2942
# Introducing errors in document  2752
# Introducing errors in document  3327
# Introducing errors in document  2193
# Introducing errors in document  3677
# Introducing errors in document  1400
# Introducing errors in document  1913
# Introducing errors in document  2579
# Introducing errors in document  2131
# Introducing errors in document  1658
# Introducing errors in document  3004
# Introducing errors in document  3645
# Introducing errors in document  1615
# Introducing errors in document  1494
# Introducing errors in document  210
# Introducing errors in document  1395
# Introducing errors in document  2597
# Introducing errors in document  2532
# Introducing errors in document  219
# Introducing errors in document  3019
# Introducing errors in document  3021
# Introducing errors in document  75
# Introducing errors in document  1148
# Introducing errors in document  2519
# Introducing errors in document  2336
# Introducing errors in document  254
# Introducing errors in document  2471
# Introducing errors in document  1708
# Introducing errors in document  779
# Introducing errors in document  2697
# Introducing errors in document  3153
# Introducing errors in document  3183
# Introducing errors in document  3277
# Introducing errors in document  1753
# Introducing errors in document  3695
# Introducing errors in document  3102
# Introducing errors in document  909
# Introducing errors in document  969
# Introducing errors in document  63
# Introducing errors in document  2018
# Introducing errors in document  1130
# Introducing errors in document  428
# Introducing errors in document  426
# Introducing errors in document  1567
# Introducing errors in document  1894
# Introducing errors in document  3323
# Introducing errors in document  1028
# Introducing errors in document  3385
# Introducing errors in document  1268
# Introducing errors in document  1403
# Introducing errors in document  877
# Introducing errors in document  1486
# Introducing errors in document  3585
# Introducing errors in document  626
# Introducing errors in document  3182
# Introducing errors in document  1240
# Introducing errors in document  1936
# Introducing errors in document  1270
# Introducing errors in document  2926
# Introducing errors in document  180
# Introducing errors in document  1677
# Introducing errors in document  1523
# Introducing errors in document  2864
# Introducing errors in document  3666
# Introducing errors in document  2863
# Introducing errors in document  777
# Introducing errors in document  583
# Introducing errors in document  181
# Introducing errors in document  1638
# Introducing errors in document  3697
# Introducing errors in document  3535
# Introducing errors in document  2588
# Introducing errors in document  1519
# Introducing errors in document  1833
# Introducing errors in document  1099
# Introducing errors in document  982
# Introducing errors in document  3325
# Introducing errors in document  1393
# Introducing errors in document  2846
# Introducing errors in document  3145
# Introducing errors in document  73
# Introducing errors in document  3234
# Introducing errors in document  542
# Introducing errors in document  3336
# Introducing errors in document  2295
# Introducing errors in document  298
# Introducing errors in document  1192
# Introducing errors in document  1554
# Introducing errors in document  763
# Introducing errors in document  1087
# Introducing errors in document  2928
# Introducing errors in document  3458
# Introducing errors in document  763
# Introducing errors in document  83
# Introducing errors in document  1173
# Introducing errors in document  719
# Introducing errors in document  3221
# Introducing errors in document  1340
# Introducing errors in document  2785
# Introducing errors in document  70
# Introducing errors in document  2454
# Introducing errors in document  24
# Introducing errors in document  1324
# Introducing errors in document  2611
# Introducing errors in document  1080
# Introducing errors in document  1401
# Introducing errors in document  343
# Introducing errors in document  3396
# Introducing errors in document  2232
# Introducing errors in document  413
# Introducing errors in document  3373
# Introducing errors in document  782
# Introducing errors in document  1317
# Introducing errors in document  728
# Introducing errors in document  2328
# Introducing errors in document  1118
# Introducing errors in document  91
# Introducing errors in document  2616
# Introducing errors in document  195
# Introducing errors in document  1321
# Introducing errors in document  1639
# Introducing errors in document  481
# Introducing errors in document  1129
# Introducing errors in document  3048
# Introducing errors in document  580
# Introducing errors in document  1201
# Introducing errors in document  606
# Introducing errors in document  2033
# Introducing errors in document  1867
# Introducing errors in document  1676
# Introducing errors in document  2314
# Introducing errors in document  3347
# Introducing errors in document  663
# Introducing errors in document  3581
# Introducing errors in document  1436
# Introducing errors in document  1811
# Introducing errors in document  1842
# Introducing errors in document  1509
# Introducing errors in document  1140
# Introducing errors in document  3428
# Introducing errors in document  2601
# Introducing errors in document  3041
# Introducing errors in document  1629
# Introducing errors in document  2761
# Introducing errors in document  1414
# Introducing errors in document  679
# Introducing errors in document  838
# Introducing errors in document  337
# Introducing errors in document  3314
# Introducing errors in document  2757
# Introducing errors in document  3024
# Introducing errors in document  3316
# Introducing errors in document  2694
# Introducing errors in document  1628
# Introducing errors in document  616
# Introducing errors in document  3091
# Introducing errors in document  2003
# Introducing errors in document  636
# Introducing errors in document  2233
# Introducing errors in document  341
# Introducing errors in document  3529
# Introducing errors in document  3272
# Introducing errors in document  1457
# Introducing errors in document  1576
# Introducing errors in document  513
# Introducing errors in document  33
# Introducing errors in document  951
# Introducing errors in document  2501
# Introducing errors in document  2733
# Introducing errors in document  1623
# Introducing errors in document  2621
# Introducing errors in document  337
# Introducing errors in document  2426
# Introducing errors in document  673
# Introducing errors in document  3658
# Introducing errors in document  1041
# Introducing errors in document  1289
# Introducing errors in document  3407
# Introducing errors in document  808
# Introducing errors in document  349
# Introducing errors in document  2248
# Introducing errors in document  1586
# Introducing errors in document  3686
# Introducing errors in document  2821
# Introducing errors in document  1973
# Introducing errors in document  3446
# Introducing errors in document  3346
# Introducing errors in document  3385
# Introducing errors in document  2121
# Introducing errors in document  858
# Introducing errors in document  3178
# Introducing errors in document  2801
# Introducing errors in document  2522
# Introducing errors in document  2123
# Introducing errors in document  513
# Introducing errors in document  471
# Introducing errors in document  642
# Introducing errors in document  1854
# Introducing errors in document  78
# Introducing errors in document  54
# Introducing errors in document  3618
# Introducing errors in document  3310
# Introducing errors in document  229
# Introducing errors in document  2031
# Introducing errors in document  2674
# Introducing errors in document  3691
# Introducing errors in document  1275
# Introducing errors in document  2420
# Introducing errors in document  1827
# Introducing errors in document  834
# Introducing errors in document  19
# Introducing errors in document  557
# Introducing errors in document  3474
# Introducing errors in document  798
# Introducing errors in document  3204
# Introducing errors in document  3343
# Introducing errors in document  953
# Introducing errors in document  3667
# Introducing errors in document  458
# Introducing errors in document  2515
# Introducing errors in document  2716
# Introducing errors in document  641
# Introducing errors in document  2392
# Introducing errors in document  954
# Introducing errors in document  3092
# Introducing errors in document  518
# Introducing errors in document  1725
# Introducing errors in document  2238
# Introducing errors in document  3467
# Introducing errors in document  948
# Introducing errors in document  556
# Introducing errors in document  2532
# Introducing errors in document  3373
# Introducing errors in document  2936
# Introducing errors in document  1736
# Introducing errors in document  1178
# Introducing errors in document  929
# Introducing errors in document  690
# Introducing errors in document  3099
# Introducing errors in document  1469
# Introducing errors in document  1920
# Introducing errors in document  197
# Introducing errors in document  398
# Introducing errors in document  374
# Introducing errors in document  1040
# Introducing errors in document  2157
# Introducing errors in document  3389
# Introducing errors in document  2035
# Introducing errors in document  2986
# Introducing errors in document  3707
# Introducing errors in document  1959
# Introducing errors in document  2977
# Introducing errors in document  3470
# Introducing errors in document  1218
# Introducing errors in document  238
# Introducing errors in document  2311
# Introducing errors in document  1233
# Introducing errors in document  1230
# Introducing errors in document  1575
# Introducing errors in document  2581
# Introducing errors in document  649
# Introducing errors in document  2454
# Introducing errors in document  1533
# Introducing errors in document  2692
# Introducing errors in document  466
# Introducing errors in document  1681
# Introducing errors in document  547
# Introducing errors in document  1246
# Introducing errors in document  2686
# Introducing errors in document  3682
# Introducing errors in document  825
# Introducing errors in document  3465
# Introducing errors in document  593
# Introducing errors in document  954
# Introducing errors in document  1068
# Introducing errors in document  1160
# Introducing errors in document  3659
# Introducing errors in document  2668
# Introducing errors in document  1715
# Introducing errors in document  2240
# Introducing errors in document  2239
# Introducing errors in document  3515
# Introducing errors in document  1541
# Introducing errors in document  2142
# Introducing errors in document  1995
# Introducing errors in document  659
# Introducing errors in document  775
# Introducing errors in document  2507
# Introducing errors in document  2113
# Introducing errors in document  1797
# Introducing errors in document  1749
# Introducing errors in document  391
# Introducing errors in document  2057
# Introducing errors in document  488
# Introducing errors in document  1245
# Introducing errors in document  2107
# Introducing errors in document  656
# Introducing errors in document  2454
# Introducing errors in document  2414
# Introducing errors in document  3566
# Introducing errors in document  312
# Introducing errors in document  353
# Introducing errors in document  2841
# Introducing errors in document  155
# Introducing errors in document  2326
# Introducing errors in document  1891
# Introducing errors in document  3457
# Introducing errors in document  2931
# Introducing errors in document  1584
# Introducing errors in document  933
# Introducing errors in document  2565
# Introducing errors in document  358
# Introducing errors in document  3703
# Introducing errors in document  2630
# Introducing errors in document  3381
# Introducing errors in document  1147
# Introducing errors in document  1547
# Introducing errors in document  826
# Introducing errors in document  2892
# Introducing errors in document  3373
# Introducing errors in document  1629
# Introducing errors in document  1997
# Introducing errors in document  373
# Introducing errors in document  2888
# Introducing errors in document  2841
# Introducing errors in document  3009
# Introducing errors in document  288
# Introducing errors in document  1393
# Introducing errors in document  1670
# Introducing errors in document  3328
# Introducing errors in document  3462
# Introducing errors in document  908
# Introducing errors in document  2099
# Introducing errors in document  2203
# Introducing errors in document  1912
# Introducing errors in document  1036
# Introducing errors in document  1042
# Introducing errors in document  2353
# Introducing errors in document  3451
# Introducing errors in document  2620
# Introducing errors in document  1186
# Introducing errors in document  2792
# Introducing errors in document  1865
# Introducing errors in document  3221
# Introducing errors in document  1727
# Introducing errors in document  606
# Introducing errors in document  832
# Introducing errors in document  771
# Introducing errors in document  1833
# Introducing errors in document  2909
# Introducing errors in document  555
# Introducing errors in document  181
# Introducing errors in document  2169
# Introducing errors in document  1843
# Introducing errors in document  12
# Introducing errors in document  676
# Introducing errors in document  160
# Introducing errors in document  2468
# Introducing errors in document  940
# Introducing errors in document  872
# Introducing errors in document  701
# Introducing errors in document  1186
# Introducing errors in document  77
# Introducing errors in document  645
# Introducing errors in document  2938
# Introducing errors in document  1170
# Introducing errors in document  1761
# Introducing errors in document  188
# Introducing errors in document  3024
# Introducing errors in document  1290
# Introducing errors in document  1804
# Introducing errors in document  624
# Introducing errors in document  499
# Introducing errors in document  1319
# Introducing errors in document  878
# Introducing errors in document  832
# Introducing errors in document  3566
# Introducing errors in document  2558
# Introducing errors in document  1259
# Introducing errors in document  1528
# Introducing errors in document  2067
# Introducing errors in document  1924
# Introducing errors in document  532
# Introducing errors in document  2587
# Introducing errors in document  1785
# Introducing errors in document  1697
# Introducing errors in document  1699
# Introducing errors in document  3690
# Introducing errors in document  1372
# Introducing errors in document  1972
# Introducing errors in document  788
# Introducing errors in document  3482
# Introducing errors in document  605
# Introducing errors in document  1187
# Introducing errors in document  1364
# Introducing errors in document  922
# Introducing errors in document  3305
# Introducing errors in document  3027
# Introducing errors in document  1956
# Introducing errors in document  3032
# Introducing errors in document  2835
# Introducing errors in document  1262
# Introducing errors in document  1298
# Introducing errors in document  1620
# Introducing errors in document  1263
# Introducing errors in document  1570
# Introducing errors in document  600
# Introducing errors in document  1429
# Introducing errors in document  1824
# Introducing errors in document  1859
# Introducing errors in document  835
# Introducing errors in document  2712
# Introducing errors in document  384
# Introducing errors in document  1145
# Introducing errors in document  1752
# Introducing errors in document  488
# Introducing errors in document  2202
# Introducing errors in document  2565
# Introducing errors in document  2456
# Introducing errors in document  1815
# Introducing errors in document  1376
# Introducing errors in document  571
# Introducing errors in document  3648
# Introducing errors in document  1603
# Introducing errors in document  712
# Introducing errors in document  559
# Introducing errors in document  1077
# Introducing errors in document  3569
# Introducing errors in document  2314
# Introducing errors in document  1338
# Introducing errors in document  1520
# Introducing errors in document  3170
# Introducing errors in document  2242
# Introducing errors in document  351
# Introducing errors in document  2513
# Introducing errors in document  1613
# Introducing errors in document  2351
# Introducing errors in document  3069
# Introducing errors in document  594
# Introducing errors in document  3395
# Introducing errors in document  2287
# Introducing errors in document  1480
# Introducing errors in document  2517
# Introducing errors in document  2323
# Introducing errors in document  2207
# Introducing errors in document  3153
# Introducing errors in document  3423
# Introducing errors in document  2969
# Introducing errors in document  2348
# Introducing errors in document  1947
# Introducing errors in document  3414
# Introducing errors in document  677
# Introducing errors in document  786
# Introducing errors in document  3566
# Introducing errors in document  407
# Introducing errors in document  1367
# Introducing errors in document  3099
# Introducing errors in document  20
# Introducing errors in document  2882
# Introducing errors in document  2343
# Introducing errors in document  1973
# Introducing errors in document  952
# Introducing errors in document  2468
# Introducing errors in document  1872
# Introducing errors in document  2332
# Introducing errors in document  1815
# Introducing errors in document  956
# Introducing errors in document  2705
# Introducing errors in document  2877
# Introducing errors in document  1055
# Introducing errors in document  2916
# Introducing errors in document  704
# Introducing errors in document  2669
# Introducing errors in document  2332
# Introducing errors in document  1530
# Introducing errors in document  1718
# Introducing errors in document  895
# Introducing errors in document  1487
# Introducing errors in document  2327
# Introducing errors in document  3182
# Introducing errors in document  42
# Introducing errors in document  2037
# Introducing errors in document  355
# Introducing errors in document  408
# Introducing errors in document  2971
# Introducing errors in document  716
# Introducing errors in document  2203
# Introducing errors in document  3083
# Introducing errors in document  3217
# Introducing errors in document  1417
# Introducing errors in document  559
# Introducing errors in document  3485
# Introducing errors in document  3265
# Introducing errors in document  2271
# Introducing errors in document  310
# Introducing errors in document  810
# Introducing errors in document  3250
# Introducing errors in document  195
# Introducing errors in document  2584
# Introducing errors in document  2056
# Introducing errors in document  339
# Introducing errors in document  2138
# Introducing errors in document  803
# Introducing errors in document  1060
# Introducing errors in document  3111
# Introducing errors in document  1932
# Introducing errors in document  2210
# Introducing errors in document  2621
# Introducing errors in document  1918
# Introducing errors in document  401
# Introducing errors in document  954
# Introducing errors in document  2745
# Introducing errors in document  1946
# Introducing errors in document  3030
# Introducing errors in document  121
# Introducing errors in document  2825
# Introducing errors in document  605
# Introducing errors in document  1547
# Introducing errors in document  268
# Introducing errors in document  148
# Introducing errors in document  3091
# Introducing errors in document  951
# Introducing errors in document  1262
# Introducing errors in document  1499
# Introducing errors in document  2829
# Introducing errors in document  1601
# Introducing errors in document  2811
# Introducing errors in document  116
# Introducing errors in document  2121
# Introducing errors in document  1740
# Introducing errors in document  640
# Introducing errors in document  2826
# Introducing errors in document  2520
# Introducing errors in document  215
# Introducing errors in document  3394
# Introducing errors in document  1335
# Introducing errors in document  2187
# Introducing errors in document  3297
# Introducing errors in document  1082
# Introducing errors in document  6
# Introducing errors in document  1162
# Introducing errors in document  407
# Introducing errors in document  691
# Introducing errors in document  1188
# Introducing errors in document  2339
# Introducing errors in document  962
# Introducing errors in document  3504
# Introducing errors in document  1678
# Introducing errors in document  1376
# Introducing errors in document  2221
# Introducing errors in document  218
# Introducing errors in document  14
# Introducing errors in document  452
# Introducing errors in document  2453
# Introducing errors in document  2401
# Introducing errors in document  537
# Introducing errors in document  3539
# Introducing errors in document  66
# Introducing errors in document  1354
# Introducing errors in document  782
# Introducing errors in document  2996
# Introducing errors in document  3560
# Introducing errors in document  2097
# Introducing errors in document  3165
# Introducing errors in document  2434
# Introducing errors in document  970
# Introducing errors in document  1198
# Introducing errors in document  726
# Introducing errors in document  2841
# Introducing errors in document  881
# Introducing errors in document  612
# Introducing errors in document  736
# Introducing errors in document  135
# Introducing errors in document  935
# Introducing errors in document  145
# Introducing errors in document  1364
# Introducing errors in document  499
# Introducing errors in document  1717
# Introducing errors in document  3547
# Introducing errors in document  2721
# Introducing errors in document  2930
# Introducing errors in document  1077
# Introducing errors in document  1777
# Introducing errors in document  2823
# Introducing errors in document  531
# Introducing errors in document  2039
# Introducing errors in document  1663
# Introducing errors in document  1098
# Introducing errors in document  2065
# Introducing errors in document  3427
# Introducing errors in document  3387
# Introducing errors in document  2829
# Introducing errors in document  2108
# Introducing errors in document  1298
# Introducing errors in document  1416
# Introducing errors in document  2693
# Introducing errors in document  1186
# Introducing errors in document  1043
# Introducing errors in document  1433
# Introducing errors in document  1416
# Introducing errors in document  1700
# Introducing errors in document  3602
# Introducing errors in document  812
# Introducing errors in document  2175
# Introducing errors in document  1472
# Introducing errors in document  2335
# Introducing errors in document  1160
# Introducing errors in document  2324
# Introducing errors in document  2568
# Introducing errors in document  1894
# Introducing errors in document  1361
# Introducing errors in document  2970
# Introducing errors in document  2026
# Introducing errors in document  626
# Introducing errors in document  1145
# Introducing errors in document  3638
# Introducing errors in document  2526
# Introducing errors in document  2189
# Introducing errors in document  297
# Introducing errors in document  3503
# Introducing errors in document  3315
# Introducing errors in document  1574
# Introducing errors in document  2397
# Introducing errors in document  1061
# Introducing errors in document  1505
# Introducing errors in document  15
# Introducing errors in document  66
# Introducing errors in document  1223
# Introducing errors in document  2109
# Introducing errors in document  1495
# Introducing errors in document  1455
# Introducing errors in document  2987
# Introducing errors in document  3691
# Introducing errors in document  144
# Introducing errors in document  1301
# Introducing errors in document  2316
# Introducing errors in document  2637
# Introducing errors in document  2716
# Introducing errors in document  75
# Introducing errors in document  3091
# Introducing errors in document  1763
# Introducing errors in document  352
# Introducing errors in document  3146
# Introducing errors in document  1027
# Introducing errors in document  1974
# Introducing errors in document  2512
# Introducing errors in document  3638
# Introducing errors in document  3479
# Introducing errors in document  2482
# Introducing errors in document  497
# Introducing errors in document  152
# Introducing errors in document  1763
# Introducing errors in document  1909
# Introducing errors in document  3522
# Introducing errors in document  2124
# Introducing errors in document  2140
# Introducing errors in document  2075
# Introducing errors in document  1240
# Introducing errors in document  1617
# Introducing errors in document  3670
# Introducing errors in document  2173
# Introducing errors in document  1454
# Introducing errors in document  2001
# Introducing errors in document  1780
# Introducing errors in document  379
# Introducing errors in document  1011
# Introducing errors in document  3454
# Introducing errors in document  1366
# Introducing errors in document  3079
# Introducing errors in document  2691
# Introducing errors in document  118
# Introducing errors in document  1982
# Introducing errors in document  1758
# Introducing errors in document  3446
# Introducing errors in document  329
# Introducing errors in document  2788
# Introducing errors in document  3588
# Introducing errors in document  1256
# Introducing errors in document  2135
# Introducing errors in document  109
# Introducing errors in document  1697
# Introducing errors in document  2102
# Introducing errors in document  2326
# Introducing errors in document  1753
# Introducing errors in document  24
# Introducing errors in document  3414
# Introducing errors in document  1564
# Introducing errors in document  3393
# Introducing errors in document  1853
# Introducing errors in document  3384
# Introducing errors in document  2603
# Introducing errors in document  1714
# Introducing errors in document  3284
# Introducing errors in document  951
# Introducing errors in document  1678
# Introducing errors in document  676
# Introducing errors in document  2116
# Introducing errors in document  2955
# Introducing errors in document  1765
# Introducing errors in document  284
# Introducing errors in document  851
# Introducing errors in document  3167
# Introducing errors in document  1619
# Introducing errors in document  844
# Introducing errors in document  1524
# Introducing errors in document  1981
# Introducing errors in document  910

# %%
abstracts_random_indexes = np.random.randint(0,abstracts.shape[0],count)
print("Generating errors in ",len(abstracts_random_indexes)," documents.")
count = 1
for i in abstracts_random_indexes:
  print("Working on document [",count,"/",len(abstracts_random_indexes),"]",end = '',flush = True)
  flag, abstract_w_error = introduce_article_error(abstracts[i])
  count = count+1
  if flag == True:
    abstracts[i] = abstract_w_error
    error_labels[i,2]=1
    error_labels[i,5]=1
# Out:
# Generating errors in  1113  documents.
# Working on document [ 1 / 1113 ]Working on document [ 2 / 1113 ]Working on document [ 3 / 1113 ]Working on document [ 4 / 1113 ]Working on document [ 5 / 1113 ]Working on document [ 6 / 1113 ]Working on document [ 7 / 1113 ]Working on document [ 8 / 1113 ]Working on document [ 9 / 1113 ]Working on document [ 10 / 1113 ]Working on document [ 11 / 1113 ]Working on document [ 12 / 1113 ]Working on document [ 13 / 1113 ]Working on document [ 14 / 1113 ]Working on document [ 15 / 1113 ]Working on document [ 16 / 1113 ]Working on document [ 17 / 1113 ]Working on document [ 18 / 1113 ]Working on document [ 19 / 1113 ]Working on document [ 20 / 1113 ]Working on document [ 21 / 1113 ]Working on document [ 22 / 1113 ]Working on document [ 23 / 1113 ]Working on document [ 24 / 1113 ]Working on document [ 25 / 1113 ]Working on document [ 26 / 1113 ]Working on document [ 27 / 1113 ]Working on document [ 28 / 1113 ]Working on document [ 29 / 1113 ]Working on document [ 30 / 1113 ]Working on document [ 31 / 1113 ]Working on document [ 32 / 1113 ]Working on document [ 33 / 1113 ]Working on document [ 34 / 1113 ]Working on document [ 35 / 1113 ]Working on document [ 36 / 1113 ]Working on document [ 37 / 1113 ]Working on document [ 38 / 1113 ]Working on document [ 39 / 1113 ]Working on document [ 40 / 1113 ]Working on document [ 41 / 1113 ]Working on document [ 42 / 1113 ]Working on document [ 43 / 1113 ]Working on document [ 44 / 1113 ]Working on document [ 45 / 1113 ]Working on document [ 46 / 1113 ]Working on document [ 47 / 1113 ]Working on document [ 48 / 1113 ]Working on document [ 49 / 1113 ]Working on document [ 50 / 1113 ]Working on document [ 51 / 1113 ]Working on document [ 52 / 1113 ]Working on document [ 53 / 1113 ]Working on document [ 54 / 1113 ]Working on document [ 55 / 1113 ]Working on document [ 56 / 1113 ]Working on document [ 57 / 1113 ]Working on document [ 58 / 1113 ]Working on document [ 59 / 1113 ]Working on document [ 60 / 1113 ]Working on document [ 61 / 1113 ]Working on document [ 62 / 1113 ]Working on document [ 63 / 1113 ]Working on document [ 64 / 1113 ]Working on document [ 65 / 1113 ]Working on document [ 66 / 1113 ]Working on document [ 67 / 1113 ]Working on document [ 68 / 1113 ]Working on document [ 69 / 1113 ]Working on document [ 70 / 1113 ]Working on document [ 71 / 1113 ]Working on document [ 72 / 1113 ]Working on document [ 73 / 1113 ]Working on document [ 74 / 1113 ]Working on document [ 75 / 1113 ]Working on document [ 76 / 1113 ]Working on document [ 77 / 1113 ]Working on document [ 78 / 1113 ]Working on document [ 79 / 1113 ]Working on document [ 80 / 1113 ]Working on document [ 81 / 1113 ]Working on document [ 82 / 1113 ]Working on document [ 83 / 1113 ]Working on document [ 84 / 1113 ]Working on document [ 85 / 1113 ]Working on document [ 86 / 1113 ]Working on document [ 87 / 1113 ]Working on document [ 88 / 1113 ]Working on document [ 89 / 1113 ]Working on document [ 90 / 1113 ]Working on document [ 91 / 1113 ]Working on document [ 92 / 1113 ]Working on document [ 93 / 1113 ]Working on document [ 94 / 1113 ]Working on document [ 95 / 1113 ]Working on document [ 96 / 1113 ]Working on document [ 97 / 1113 ]Working on document [ 98 / 1113 ]Working on document [ 99 / 1113 ]Working on document [ 100 / 1113 ]Working on document [ 101 / 1113 ]Working on document [ 102 / 1113 ]Working on document [ 103 / 1113 ]Working on document [ 104 / 1113 ]Working on document [ 105 / 1113 ]Working on document [ 106 / 1113 ]Working on document [ 107 / 1113 ]Working on document [ 108 / 1113 ]Working on document [ 109 / 1113 ]Working on document [ 110 / 1113 ]Working on document [ 111 / 1113 ]Working on document [ 112 / 1113 ]Working on document [ 113 / 1113 ]Working on document [ 114 / 1113 ]Working on document [ 115 / 1113 ]Working on document [ 116 / 1113 ]Working on document [ 117 / 1113 ]Working on document [ 118 / 1113 ]Working on document [ 119 / 1113 ]Working on document [ 120 / 1113 ]Working on document [ 121 /  ...

# %%
from tqdm.notebook import tqdm_notebook
import time

# %%
abstracts_random_indexes = np.random.randint(0,abstracts.shape[0],count)
print("Generating errors in ",len(abstracts_random_indexes)," random documents.")
count = 1
for i in tqdm_notebook(abstracts_random_indexes):
  
  abstract_w_error = introduce_incorrect_word_error(abstracts[i])
  count = count+1
  abstracts[i] = abstract_w_error
  error_labels[i,3]=1
  error_labels[i,5]=1
# Out:
# Generating errors in  1114  random documents.
#   0%|          | 0/1114 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Replacing  bee  with  be
# be
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  right  with  rite
# rite
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  its  with  it's
# it's
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  martial  with  marshal
# marshal
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  freeze  with  frees
# frees
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  wind  with  whined
# whined
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  lead  with  led
# led
# Replacing  for  with  fore
# fore
# Replacing  male  with  mail
# mail
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  ring  with  wring
# wring
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  who's  with  whose
# whose
# Replacing  it's  with  its
# its
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  shell  with  shall
# shall
# Replacing  or  with  oar
# oar
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  whose  with  who's
# who's
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  place  with  plaice
# plaice
# Replacing  some  with  sum
# sum
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  by  with  buy
# buy
# Replacing  buy  with  by
# by
# Replacing  ring  with  wring
# wring
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  board  with  bored
# bored
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  air  with  heir
# heir
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  base  with  bass
# bass
# Replacing  bases  with  basis
# basis
# Replacing  wood  with  would
# would
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  roll  with  role
# role
# Replacing  steel  with  steal
# steal
# Replacing  or  with  oar
# oar
# Replacing  break  with  brake
# brake
# Replacing  by  with  buy
# buy
# Replacing  four  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  their  with  there
# there
# Replacing  be  with  bee
# bee
# Replacing  rays  with  raise
# raise
# Replacing  oral  with  aural
# aural
# Replacing  or  with  oar
# oar
# Replacing  tract  with  tracked
# tracked
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  sew  with  so
# so
# Replacing  to  with  too
# too
# Replacing  alter  with  altar
# altar
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  mode  with  mowed
# mowed
# Replacing  suit  with  soot
# soot
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  air  with  heir
# heir
# Replacing  ring  with  wring
# wring
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  road  with  rode
# rode
# Replacing  more  with  moor
# moor
# Replacing  for  with  fore
# fore
# Replacing  board  with  bored
# bored
# Replacing  stationary  with  stationery
# stationery
# Replacing  to  with  too
# too
# Replacing  shell  with  shall
# shall
# Replacing  or  with  oar
# oar
# Replacing  roll  with  role
# role
# Replacing  by  with  buy
# buy
# Replacing  plane  with  plain
# plain
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  leak  with  leek
# leek
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  way  with  weigh
# weigh
# Replacing  be  with  bee
# bee
# Replacing  stationary  with  stationery
# stationery
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  wood  with  would
# would
# Replacing  straight  with  strait
# strait
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  tail  with  tale
# tale
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  its  with  it's
# it's
# Replacing  nose  with  nose
# nose
# Replacing  where  with  wear
# wear
# Replacing  mode  with  mowed
# mowed
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  patients  with  patience
# patience
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  too  with  to
# to
# Replacing  presents  with  presence
# presence
# Replacing  to  with  too
# too
# Replacing  place  with  plaice
# plaice
# Replacing  its  with  it's
# it's
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  effect  with  affect
# affect
# Replacing  to  with  too
# too
# Replacing  pole  with  poll
# poll
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  pair  with  pare
# pare
# Replacing  to  with  too
# too
# Replacing  bow  with  bough
# bough
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  whose  with  who's
# who's
# Replacing  so  with  sew
# sew
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  shell  with  shall
# shall
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  idle  with  idol
# idol
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  forward  with  foreword
# foreword
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  led  with  lead
# lead
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  piece  with  peace
# peace
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  their  with  there
# there
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  their  with  there
# there
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  by  with  buy
# buy
# Replacing  made  with  maid
# maid
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  board  with  bored
# bored
# Replacing  waste  with  waist
# waist
# Replacing  would  with  wood
# wood
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  weather  with  wether
# wether
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  whether  with  wether
# wether
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  place  with  plaice
# plaice
# Replacing  wind  with  whined
# whined
# Replacing  or  with  oar
# oar
# Replacing  through  with  threw
# threw
# Replacing  rays  with  raise
# raise
# Replacing  sun  with  son
# son
# Replacing  band  with  banned
# banned
# Replacing  rows  with  rose
# rose
# Replacing  or  with  oar
# oar
# Replacing  brake  with  break
# break
# Replacing  some  with  sum
# sum
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  towed  with  toed
# toed
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  buy  with  by
# by
# Replacing  who's  with  whose
# whose
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  ceiling  with  sealing
# sealing
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  by  with  buy
# buy
# Replacing  buy  with  by
# by
# Replacing  through  with  threw
# threw
# Replacing  or  with  oar
# oar
# Replacing  more  with  moor
# moor
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  air  with  heir
# heir
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  through  with  threw
# threw
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  pore  with  poor
# poor
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  their  with  there
# there
# Replacing  weight  with  wait
# wait
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  to  with  too
# too
# Replacing  there  with  their
# their
# Replacing  through  with  threw
# threw
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  no  with  know
# know
# Replacing  through  with  threw
# threw
# Replacing  plain  with  plane
# plane
# Replacing  buy  with  by
# by
# Replacing  for  with  fore
# fore
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  through  with  threw
# threw
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  their  with  there
# there
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  so  with  sew
# sew
# Replacing  there  with  their
# their
# Replacing  where  with  wear
# wear
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  base  with  bass
# bass
# Replacing  for  with  fore
# fore
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  bore  with  boor
# boor
# Replacing  by  with  buy
# buy
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  way  with  weigh
# weigh
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  moor  with  more
# more
# Replacing  for  with  fore
# fore
# Replacing  wet  with  whet
# whet
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  stationary  with  stationery
# stationery
# Replacing  place  with  plaice
# plaice
# Replacing  so  with  sew
# sew
# Replacing  plane  with  plain
# plain
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  base  with  bass
# bass
# Replacing  lock  with  loch
# loch
# Replacing  or  with  oar
# oar
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  red  with  read
# read
# Replacing  build  with  billed
# billed
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  board  with  bored
# bored
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  rest  with  wrest
# wrest
# Replacing  hold  with  holed
# holed
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  some  with  sum
# sum
# Replacing  made  with  maid
# maid
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  whined  with  wind
# wind
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  air  with  heir
# heir
# Replacing  by  with  buy
# buy
# Replacing  oar  with  or
# or
# Replacing  moor  with  more
# more
# Replacing  too  with  to
# to
# Replacing  or  with  oar
# oar
# Replacing  bored  with  board
# board
# Replacing  root  with  route
# route
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  too  with  to
# to
# Replacing  manor  with  manner
# manner
# Replacing  fore  with  for
# for
# Replacing  bass  with  base
# base
# Replacing  for  with  fore
# fore
# Replacing  buy  with  by
# by
# Replacing  be  with  bee
# bee
# Replacing  fore  with  for
# for
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  mail  with  male
# male
# Replacing  buy  with  by
# by
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  alter  with  altar
# altar
# Replacing  their  with  there
# there
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  route  with  root
# root
# Replacing  by  with  buy
# buy
# Replacing  sew  with  so
# so
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  ware  with  wear
# wear
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  be  with  bee
# bee
# Replacing  bore  with  boor
# boor
# Replacing  to  with  too
# too
# Replacing  ant  with  aunt
# aunt
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  sea  with  see
# see
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  hole  with  whole
# whole
# Replacing  be  with  bee
# bee
# Replacing  ring  with  wring
# wring
# Replacing  rest  with  wrest
# wrest
# Replacing  piece  with  peace
# peace
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  whose  with  who's
# who's
# Replacing  whole  with  hole
# hole
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  hour  with  our
# our
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  there  with  their
# their
# Replacing  no  with  know
# know
# Replacing  weight  with  wait
# wait
# Replacing  for  with  fore
# fore
# Replacing  fore  with  for
# for
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  where  with  wear
# wear
# Replacing  to  with  too
# too
# Replacing  pair  with  pare
# pare
# Replacing  by  with  buy
# buy
# Replacing  its  with  it's
# it's
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  board  with  bored
# bored
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  place  with  plaice
# plaice
# Replacing  by  with  buy
# buy
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  lock  with  loch
# loch
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  sea  with  see
# see
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  waste  with  waist
# waist
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  so  with  sew
# sew
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  effect  with  affect
# affect
# Replacing  for  with  fore
# fore
# Replacing  grate  with  great
# great
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  place  with  plaice
# plaice
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  past  with  passed
# passed
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  through  with  threw
# threw
# Replacing  ball  with  bawl
# bawl
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  sun  with  son
# son
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  pair  with  pare
# pare
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  pair  with  pare
# pare
# Replacing  fore  with  for
# for
# Replacing  two  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  roll  with  role
# role
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  bore  with  boor
# boor
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  made  with  maid
# maid
# Replacing  more  with  moor
# moor
# Replacing  no  with  know
# know
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  pole  with  poll
# poll
# Replacing  by  with  buy
# buy
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  pair  with  pare
# pare
# Replacing  made  with  maid
# maid
# Replacing  plane  with  plain
# plain
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  bases  with  basis
# basis
# Replacing  or  with  oar
# oar
# Replacing  its  with  it's
# it's
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  way  with  weigh
# weigh
# Replacing  roll  with  role
# role
# Replacing  or  with  oar
# oar
# Replacing  shell  with  shall
# shall
# Replacing  mode  with  mowed
# mowed
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  some  with  sum
# sum
# Replacing  sign  with  sine
# sine
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  lead  with  led
# led
# Replacing  their  with  there
# there
# Replacing  blew  with  blue
# blue
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  read  with  red
# red
# Replacing  buy  with  by
# by
# Replacing  fore  with  for
# for
# Replacing  blue  with  blew
# blew
# Replacing  led  with  lead
# lead
# Replacing  red  with  read
# read
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  stationary  with  stationery
# stationery
# Replacing  manner  with  manor
# manor
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  hole  with  whole
# whole
# Replacing  by  with  buy
# buy
# Replacing  foreword  with  forward
# forward
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  forward  with  foreword
# foreword
# Replacing  bee  with  be
# be
# Replacing  ring  with  wring
# wring
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  there  with  their
# their
# Replacing  four  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  manner  with  manor
# manor
# Replacing  stationary  with  stationery
# stationery
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  board  with  bored
# bored
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  buy  with  by
# by
# Replacing  loch  with  lock
# lock
# Replacing  be  with  bee
# bee
# Replacing  fore  with  for
# for
# Replacing  or  with  oar
# oar
# Replacing  bee  with  be
# be
# Replacing  too  with  to
# to
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  piece  with  peace
# peace
# Replacing  wrapped  with  rapped
# rapped
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  bee  with  be
# be
# Replacing  for  with  fore
# fore
# Replacing  pair  with  pare
# pare
# Replacing  to  with  too
# too
# Replacing  air  with  heir
# heir
# Replacing  to  with  too
# too
# Replacing  rain  with  reign
# reign
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  manner  with  manor
# manor
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  mail  with  male
# male
# Replacing  oar  with  or
# or
# Replacing  ball  with  bawl
# bawl
# Replacing  buy  with  by
# by
# Replacing  be  with  bee
# bee
# Replacing  bawl  with  ball
# ball
# Replacing  bee  with  be
# be
# Replacing  for  with  fore
# fore
# Replacing  base  with  bass
# bass
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  air  with  heir
# heir
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  weight  with  wait
# wait
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  pair  with  pare
# pare
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  whether  with  wether
# wether
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  hanger  with  hangar
# hangar
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  for  with  fore
# fore
# Replacing  pole  with  poll
# poll
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  whether  with  wether
# wether
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  read  with  red
# red
# Replacing  there  with  their
# their
# Replacing  more  with  moor
# moor
# Replacing  be  with  bee
# bee
# Replacing  pair  with  pare
# pare
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  made  with  maid
# maid
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  so  with  sew
# sew
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  ring  with  wring
# wring
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  buy  with  by
# by
# Replacing  fore  with  for
# for
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  through  with  threw
# threw
# Replacing  straight  with  strait
# strait
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  waste  with  waist
# waist
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  some  with  sum
# sum
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  plain  with  plane
# plane
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  finish  with  Finnish
# Finnish
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  there  with  their
# their
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  there  with  their
# their
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  there  with  their
# their
# Replacing  effect  with  affect
# affect
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  there  with  their
# their
# Replacing  by  with  buy
# buy
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  band  with  banned
# banned
# Replacing  by  with  buy
# buy
# Replacing  oar  with  or
# or
# Replacing  taut  with  taught
# taught
# Replacing  too  with  to
# to
# Replacing  moor  with  more
# more
# Replacing  altar  with  alter
# alter
# Replacing  poll  with  pole
# pole
# Replacing  fore  with  for
# for
# Replacing  by  with  buy
# buy
# Replacing  it's  with  its
# its
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  base  with  bass
# bass
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  oar  with  or
# or
# Replacing  air  with  heir
# heir
# Replacing  threw  with  through
# through
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  oral  with  aural
# aural
# Replacing  or  with  oar
# oar
# Replacing  its  with  it's
# it's
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  rest  with  wrest
# wrest
# Replacing  stake  with  steak
# steak
# Replacing  hole  with  whole
# whole
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  waste  with  waist
# waist
# Replacing  for  with  fore
# fore
# Replacing  alter  with  altar
# altar
# Replacing  manner  with  manor
# manor
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  waist  with  waste
# waste
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  waste  with  waist
# waist
# Replacing  too  with  to
# to
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  shell  with  shall
# shall
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  bee  with  be
# be
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  ring  with  wring
# wring
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  sealing  with  ceiling
# ceiling
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  bear  with  bare
# bare
# Replacing  by  with  buy
# buy
# Replacing  wear  with  ware
# ware
# Replacing  tear  with  tare
# tare
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  wet  with  whet
# whet
# Replacing  be  with  bee
# bee
# Replacing  there  with  their
# their
# Replacing  by  with  buy
# buy
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  piece  with  peace
# peace
# Replacing  brake  with  break
# break
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  for  with  fore
# fore
# Replacing  moor  with  more
# more
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  or  with  oar
# oar
# Replacing  heir  with  air
# air
# Replacing  bee  with  be
# be
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  shear  with  sheer
# sheer
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  there  with  their
# their
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  shall  with  shell
# shell
# Replacing  oar  with  or
# or
# Replacing  role  with  roll
# roll
# Replacing  fore  with  for
# for
# Replacing  bored  with  board
# board
# Replacing  shell  with  shall
# shall
# Replacing  stationery  with  stationary
# stationary
# Replacing  roll  with  role
# role
# Replacing  or  with  oar
# oar
# Replacing  too  with  to
# to
# Replacing  plane  with  plain
# plain
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  road  with  rode
# rode
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  presence  with  presents
# presents
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  so  with  sew
# sew
# Replacing  there  with  their
# their
# Replacing  two  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  be  with  bee
# bee
# Replacing  bee  with  be
# be
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  air  with  heir
# heir
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  wet  with  whet
# whet
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  base  with  bass
# bass
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  threw  with  through
# through
# Replacing  seam  with  seem
# seem
# Replacing  too  with  to
# to
# Replacing  seem  with  seam
# seam
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  buy  with  by
# by
# Replacing  oar  with  or
# or
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  base  with  bass
# bass
# Replacing  fore  with  for
# for
# Replacing  bass  with  base
# base
# Replacing  bee  with  be
# be
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  tear  with  tare
# tare
# Replacing  grate  with  great
# great
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  whether  with  wether
# wether
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  there  with  their
# their
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  place  with  plaice
# plaice
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  finish  with  Finnish
# Finnish
# Replacing  or  with  oar
# oar
# Replacing  their  with  there
# there
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  be  with  bee
# bee
# Replacing  threw  with  through
# through
# Replacing  for  with  fore
# fore
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  so  with  sew
# sew
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  buy  with  by
# by
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  moor  with  more
# more
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  maid  with  made
# made
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  seam  with  seem
# seem
# Replacing  ball  with  bawl
# bawl
# Replacing  rays  with  raise
# raise
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  board  with  bored
# bored
# Replacing  made  with  maid
# maid
# Replacing  more  with  moor
# moor
# Replacing  its  with  it's
# it's
# Replacing  wear  with  ware
# ware
# Replacing  break  with  brake
# brake
# Replacing  or  with  oar
# oar
# Replacing  weight  with  wait
# wait
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  their  with  there
# there
# Replacing  weather  with  wether
# wether
# Replacing  for  with  fore
# fore
# Replacing  sun  with  son
# son
# Replacing  base  with  bass
# bass
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  whether  with  wether
# wether
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  weight  with  wait
# wait
# Replacing  wear  with  ware
# ware
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  road  with  rode
# rode
# Replacing  passed  with  past
# past
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  where  with  wear
# wear
# Replacing  base  with  bass
# bass
# Replacing  board  with  bored
# bored
# Replacing  way  with  weigh
# weigh
# Replacing  made  with  maid
# maid
# Replacing  to  with  too
# too
# Replacing  rest  with  wrest
# wrest
# Replacing  more  with  moor
# moor
# Replacing  swayed  with  suede
# suede
# Replacing  by  with  buy
# buy
# Replacing  minor  with  miner
# miner
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  so  with  sew
# sew
# Replacing  to  with  too
# too
# Replacing  threw  with  through
# through
# Replacing  oar  with  or
# or
# Replacing  too  with  to
# to
# Replacing  moor  with  more
# more
# Replacing  there  with  their
# their
# Replacing  bee  with  be
# be
# Replacing  through  with  threw
# threw
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  buy  with  by
# by
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  manor  with  manner
# manner
# Replacing  by  with  buy
# buy
# Replacing  stationery  with  stationary
# stationary
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  shear  with  sheer
# sheer
# Replacing  or  with  oar
# oar
# Replacing  oral  with  aural
# aural
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  mowed  with  mode
# mode
# Replacing  right  with  rite
# rite
# Replacing  hold  with  holed
# holed
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  buy  with  by
# by
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  base  with  bass
# bass
# Replacing  its  with  it's
# it's
# Replacing  their  with  there
# there
# Replacing  sew  with  so
# so
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  some  with  sum
# sum
# Replacing  to  with  too
# too
# Replacing  led  with  lead
# lead
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  manner  with  manor
# manor
# Replacing  whose  with  who's
# who's
# Replacing  ceiling  with  sealing
# sealing
# Replacing  by  with  buy
# buy
# Replacing  plane  with  plain
# plain
# Replacing  to  with  too
# too
# Replacing  no  with  know
# know
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  bore  with  boor
# boor
# Replacing  through  with  threw
# threw
# Replacing    with  toad
# toad
# Replacing  buy  with  by
# by
# Replacing  too  with  to
# to
# Replacing  rite  with  right
# right
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  ring  with  wring
# wring
# Replacing  to  with  too
# too
# Replacing  hold  with  holed
# holed
# Replacing  by  with  buy
# buy
# Replacing  more  with  moor
# moor
# Replacing  there  with  their
# their
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  more  with  moor
# moor
# Replacing  for  with  fore
# fore
# Replacing  their  with  there
# there
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  no  with  know
# know
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  its  with  it's
# it's
# Replacing  for  with  fore
# fore
# Replacing  through  with  threw
# threw
# Replacing  or  with  oar
# oar
# Replacing  where  with  wear
# wear
# Replacing  base  with  bass
# bass
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  its  with  it's
# it's
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  patients  with  patience
# patience
# Replacing  by  with  buy
# buy
# Replacing  where  with  wear
# wear
# Replacing    with  toad
# toad
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  its  with  it's
# it's
# Replacing  or  with  oar
# oar
# Replacing  four  with  fore
# fore
# Replacing  two  with  too
# too
# Replacing  sole  with  soul
# soul
# Replacing  too  with  to
# to
# Replacing  soul  with  sole
# sole
# Replacing  fore  with  for
# for
# Replacing  bass  with  base
# base
# Replacing  bawl  with  ball
# ball
# Replacing  mussel  with  muscle
# muscle
# Replacing  role  with  roll
# roll
# Replacing  buy  with  by
# by
# Replacing  roll  with  role
# role
# Replacing  fore  with  for
# for
# Replacing  bore  with  boor
# boor
# Replacing  so  with  sew
# sew
# Replacing  too  with  to
# to
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  to  with  too
# too
# Replacing  bases  with  basis
# basis
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  root  with  route
# route
# Replacing  route  with  root
# root
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  by  with  buy
# buy
# Replacing  lock  with  loch
# loch
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  wood  with  would
# would
# Replacing  be  with  bee
# bee
# Replacing  too  with  to
# to
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  piece  with  peace
# peace
# Replacing  more  with  moor
# moor
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  billed  with  build
# build
# Replacing  its  with  it's
# it's
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  ring  with  wring
# wring
# Replacing  be  with  bee
# bee
# Replacing  hold  with  holed
# holed
# Replacing  vane  with  vain
# vain
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  threw  with  through
# through
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  past  with  passed
# passed
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  way  with  weigh
# weigh
# Replacing  here  with  hear
# hear
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# ...
# Replacing  or  with  oar
# oar
# Replacing  bawl  with  ball
# ball
# Replacing  by  with  buy
# buy
# Replacing  aloud  with  allowed
# allowed
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  there  with  their
# their
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  borne  with  born
# born
# Replacing  or  with  oar
# oar
# Replacing  it's  with  its
# its
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  made  with  maid
# maid
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  male  with  mail
# mail
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  place  with  plaice
# plaice
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  four  with  fore
# fore
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  tea  with  tee
# tee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  shear  with  sheer
# sheer
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  air  with  heir
# heir
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  ceiling  with  sealing
# sealing
# Replacing  to  with  too
# too
# Replacing  effect  with  affect
# affect
# Replacing  too  with  to
# to
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  air  with  heir
# heir
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  manor  with  manner
# manner
# Replacing  peace  with  piece
# piece
# Replacing  buy  with  by
# by
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  too  with  to
# to
# Replacing  piece  with  peace
# peace
# Replacing  for  with  fore
# fore
# Replacing  meat  with  meet
# meet
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  more  with  moor
# moor
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  steel  with  steal
# steal
# Replacing  would  with  wood
# wood
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  made  with  maid
# maid
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  its  with  it's
# it's
# Replacing  wave  with  waive
# waive
# Replacing  plane  with  plain
# plain
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  two  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  where  with  wear
# wear
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  so  with  sew
# sew
# Replacing  plane  with  plain
# plain
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  place  with  plaice
# plaice
# Replacing  oral  with  aural
# aural
# Replacing  two  with  too
# too
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  shall  with  shell
# shell
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  genes  with  jeans
# jeans
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  too  with  to
# to
# Replacing  oar  with  or
# or
# Replacing  for  with  fore
# fore
# Replacing  buy  with  by
# by
# Replacing  foreword  with  forward
# forward
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  fore  with  for
# for
# Replacing  moor  with  more
# more
# Replacing  too  with  to
# to
# Replacing  bee  with  be
# be
# Replacing  idol  with  idle
# idle
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  effect  with  affect
# affect
# Replacing  to  with  too
# too
# Replacing  shell  with  shall
# shall
# Replacing  for  with  fore
# fore
# Replacing  right  with  rite
# rite
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  oar  with  or
# or
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  their  with  there
# there
# Replacing  be  with  bee
# bee
# Replacing  threw  with  through
# through
# Replacing  too  with  to
# to
# Replacing  through  with  threw
# threw
# Replacing  buy  with  by
# by
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  banned  with  band
# band
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  oar  with  or
# or
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  sew  with  so
# so
# Replacing  to  with  too
# too
# Replacing  bee  with  be
# be
# Replacing  fore  with  for
# for
# Replacing  to  with  too
# too
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  basis  with  bases
# bases
# Replacing  for  with  fore
# fore
# Replacing  mode  with  mowed
# mowed
# Replacing  to  with  too
# too
# Replacing  hold  with  holed
# holed
# Replacing  or  with  oar
# oar
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  base  with  bass
# bass
# Replacing  pair  with  pare
# pare
# Replacing  to  with  too
# too
# Replacing  ring  with  wring
# wring
# Replacing  right  with  rite
# rite
# Replacing  by  with  buy
# buy
# Replacing  whole  with  hole
# hole
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  rest  with  wrest
# wrest
# Replacing  be  with  bee
# bee
# Replacing  through  with  threw
# threw
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  bow  with  bough
# bough
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  place  with  plaice
# plaice
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  too  with  to
# to
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  there  with  their
# their
# Replacing  oar  with  or
# or
# Replacing  buy  with  by
# by
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  manor  with  manner
# manner
# Replacing  bee  with  be
# be
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  wear  with  ware
# ware
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  bee  with  be
# be
# Replacing  too  with  to
# to
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  presents  with  presence
# presence
# Replacing  or  with  oar
# oar
# Replacing  basis  with  bases
# bases
# Replacing  passed  with  past
# past
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  through  with  threw
# threw
# Replacing  so  with  sew
# sew
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  weight  with  wait
# wait
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  threw  with  through
# through
# Replacing  fore  with  for
# for
# Replacing  more  with  moor
# moor
# Replacing  air  with  heir
# heir
# Replacing  presence  with  presents
# presents
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  buy  with  by
# by
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  manor  with  manner
# manner
# Replacing  bee  with  be
# be
# Replacing  by  with  buy
# buy
# Replacing  too  with  to
# to
# Replacing  air  with  heir
# heir
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  through  with  threw
# threw
# Replacing  two  with  too
# too
# Replacing  peer  with  pier
# pier
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  allowed  with  aloud
# aloud
# Replacing  or  with  oar
# oar
# Replacing  no  with  know
# know
# Replacing  so  with  sew
# sew
# Replacing  whether  with  wether
# wether
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  bee  with  be
# be
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  there  with  their
# their
# Replacing  base  with  bass
# bass
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  hanger  with  hangar
# hangar
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  whose  with  who's
# who's
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  bread  with  bred
# bred
# Replacing  sale  with  sail
# sail
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  too  with  to
# to
# Replacing  ware  with  wear
# wear
# Replacing  fore  with  for
# for
# Replacing  pare  with  pair
# pair
# Replacing  too  with  to
# to
# Replacing  maid  with  made
# made
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  base  with  bass
# bass
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  its  with  it's
# it's
# Replacing  effect  with  affect
# affect
# Replacing  through  with  threw
# threw
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  there  with  their
# their
# Replacing  buy  with  by
# by
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  for  with  fore
# fore
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  incite  with  insight
# insight
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  roll  with  role
# role
# Replacing  its  with  it's
# it's
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  through  with  threw
# threw
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  rows  with  rose
# rose
# Replacing  be  with  bee
# bee
# Replacing  to  with  too
# too
# Replacing  or  with  oar
# oar
# Replacing  to  with  too
# too
# Replacing  their  with  there
# there
# Replacing  too  with  to
# to
# Replacing  fore  with  for
# for
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  manner  with  manor
# manor
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  two  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  yoke  with  yolk
# yolk
# Replacing  or  with  oar
# oar
# Replacing  steel  with  steal
# steal
# Replacing  piece  with  peace
# peace
# Replacing  two  with  too
# too
# Replacing  made  with  maid
# maid
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  some  with  sum
# sum
# Replacing  whole  with  hole
# hole
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  oar  with  or
# or
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  through  with  threw
# threw
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  for  with  fore
# fore
# Replacing  so  with  sew
# sew
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  threw  with  through
# through
# Replacing  for  with  fore
# fore
# Replacing  fore  with  for
# for
# Replacing  for  with  fore
# fore
# Replacing  to  with  too
# too
# Replacing  more  with  moor
# moor
# Replacing  or  with  oar
# oar
# Replacing  pair  with  pare
# pare
# Replacing  to  with  too
# too
# Replacing  mode  with  mowed
# mowed
# Replacing  no  with  know
# know
# Replacing  for  with  fore
# fore
# Replacing  mode  with  mowed
# mowed
# Replacing  or  with  oar
# oar
# Replacing  by  with  buy
# buy
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  read  with  red
# red
# Replacing  fore  with  for
# for
# Replacing  for  with  fore
# fore
# Replacing  pair  with  pare
# pare
# Replacing  for  with  fore
# fore
# Replacing  where  with  wear
# wear
# Replacing  for  with  fore
# fore
# Replacing  for  with  fore
# fore
# Replacing  roll  with  role
# role
# Replacing  buy  with  by
# by
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  bee  with  be
# be
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  more  with  moor
# moor
# Replacing  to  with  too
# too
# Replacing  by  with  buy
# buy
# Replacing  or  with  oar
# oar
# Replacing  for  with  fore
# fore
# Replacing  base  with  bass
# bass
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  or  with  oar
# oar
# Replacing  it's  with  its
# its
# Replacing  made  with  maid
# maid
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  base  with  bass
# bass
# Replacing  to  with  too
# too
# Replacing  led  with  lead
# lead
# Replacing  by  with  buy
# buy
# Replacing  to  with  too
# too
# Replacing  for  with  fore
# fore
# Replacing  base  with  bass
# bass
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  ceiling  with  sealing
# sealing
# Replacing  by  with  buy
# buy
# Replacing  for  with  fore
# fore
# Replacing  oar  with  or
# or
# Replacing  to  with  too
# too
# Replacing  fore  with  for
# for
# Replacing  too  with  to
# to
# Replacing  moor  with  more
# more
# Replacing  buy  with  by
# by
# Replacing  oar  with  or
# or
# Replacing  board  with  bored
# bored
# Replacing  moor  with  more
# more
# Replacing  bored  with  board
# board
# Replacing  made  with  maid
# maid
# Replacing  to  with  too
# too
# Replacing  whose  with  who's
# who's
# Replacing  to  with  too
# too
# Replacing  be  with  bee
# bee
# Replacing  through  with  threw
# threw

# %%
abstracts_random_indexes = np.random.randint(0,abstracts.shape[0],count)
for i in tqdm_notebook(abstracts_random_indexes):
  abstract_w_error = introduce_spelling_errors(abstracts[i])
  abstracts[i] = abstract_w_error
  error_labels[i,4]=1
  error_labels[i,5]=1
# Out:
#   0%|          | 0/1115 [00:00<?, ?it/s]

# %%
df_abstracts_errors = pd.DataFrame({'abstracts':abstracts,'err_1':error_labels[:,0],'err_2':error_labels[:,1],'err_3':error_labels[:,2],'err_4':error_labels[:,3],'err_5':error_labels[:,4],'grammatically_incorrect':error_labels[:,5],})

# %%
labels_wo_errors = np.zeros(shape=(df_wo_errors.shape[0],6),dtype=int)
abstracts_correct = np.array(df_wo_errors.abstract)
df_abstracts_correct = pd.DataFrame({'abstracts':abstracts_correct,'err_1':labels_wo_errors[:,0],'err_2':labels_wo_errors[:,1],'err_3':labels_wo_errors[:,2],'err_4':labels_wo_errors[:,3],'err_5':labels_wo_errors[:,4],'grammatically_incorrect':labels_wo_errors[:,5],})
df_final = pd.concat([df_abstracts_errors,df_abstracts_correct])
df_final = df_final.sample(frac=1, random_state=21)

# %%
df_final.to_csv('/content/drive/MyDrive/Colab Notebooks/thesis_PQAI/grammer_error_dataset/train.csv',index=False)

# %%
df_final.sample(frac=0.001,random_state=57)
# Out:
#                                               abstracts  ...  grammatically_incorrect
# 2633  rthe portable device foir secured loads , incl...  ...                        1
# 5555  an air conditioning system with a common refri...  ...                        0
# 3270  a instruction translation look - aside buffer ...  ...                        1
# 1050  process und apparatus foir the gro pf films of...  ...                        1
# 1167  an image forming apparatus having a main body ...  ...                        0
# 1993  a lever electromechanical valve actuator assem...  ...                        0
# 7869  a bracket and sensor body of a magnetic sensor...  ...                        0
# 1576  a corona treatment system has a corona treatme...  ...                        0
# 1269  remote sensing method and apparatus wherein sp...  ...                        1
# 6803  a method and system for generating channel est...  ...                        0
# 1703  a system and method for deploying a satellite ...  ...                        0
# 2490  a machine for automatically sewing the opposit...  ...                        0
#
# [12 rows x 7 columns]
